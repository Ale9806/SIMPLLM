# %% [markdown]
# DRKG
#
# Adapted from: https://github.com/gnn4dr/DRKG/blob/master/drkg_with_dgl/loading_drkg_in_dgl.ipynb

# %%
import pandas as pd
import numpy as np
import os

# %%
# !pip install pandas numpy tabulate chembl_downloader pyarrow
# Out:
# Requirement already satisfied: pandas in /Users/selinapi/opt/anaconda3/envs/simp_llm/lib/python3.11/site-packages (2.0.1)
# Requirement already satisfied: numpy in /Users/selinapi/opt/anaconda3/envs/simp_llm/lib/python3.11/site-packages (1.24.3)
# Requirement already satisfied: tabulate in /Users/selinapi/opt/anaconda3/envs/simp_llm/lib/python3.11/site-packages (0.9.0)
# Requirement already satisfied: chembl_downloader in /Users/selinapi/opt/anaconda3/envs/simp_llm/lib/python3.11/site-packages (0.4.2)
# Requirement already satisfied: pyarrow in /Users/selinapi/opt/anaconda3/envs/simp_llm/lib/python3.11/site-packages (12.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/selinapi/opt/anaconda3/envs/simp_llm/lib/python3.11/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/selinapi/opt/anaconda3/envs/simp_llm/lib/python3.11/site-packages (from pandas) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /Users/selinapi/opt/anaconda3/envs/simp_llm/lib/python3.11/site-packages (from pandas) (2023.3)
# Requirement already satisfied: click in /Users/selinapi/opt/anaconda3/envs/simp_llm/lib/python3.11/site-packages (from chembl_downloader) (8.1.3)
# Requirement already satisfied: more-click in /Users/selinapi/opt/anaconda3/envs/simp_llm/lib/python3.11/site-packages (from chembl_downloader) (0.1.2)
# Requirement already satisfied: pystow in /Users/selinapi/opt/anaconda3/envs/simp_llm/lib/python3.11/site-packages (from chembl_downloader) (0.5.0)
# Requirement already satisfied: tqdm in /Users/selinapi/opt/anaconda3/envs/simp_llm/lib/python3.11/site-packages (from chembl_downloader) (4.65.0)
# Requirement already satisfied: six>=1.5 in /Users/selinapi/opt/anaconda3/envs/simp_llm/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: requests in /Users/selinapi/opt/anaconda3/envs/simp_llm/lib/python3.11/site-packages (from pystow->chembl_downloader) (2.30.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/selinapi/opt/anaconda3/envs/simp_llm/lib/python3.11/site-packages (from requests->pystow->chembl_downloader) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/selinapi/opt/anaconda3/envs/simp_llm/lib/python3.11/site-packages (from requests->pystow->chembl_downloader) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/selinapi/opt/anaconda3/envs/simp_llm/lib/python3.11/site-packages (from requests->pystow->chembl_downloader) (2.0.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/selinapi/opt/anaconda3/envs/simp_llm/lib/python3.11/site-packages (from requests->pystow->chembl_downloader) (2023.5.7)

# %%
from SIMP_LLM.DRKG_loading   import  get_triplets, read_tsv,filter_drkg,map_drkg_relationships,filter_interaction_subset,print_head
from SIMP_LLM.DRKG_translate import  load_lookups
from SIMP_LLM.DRKG_entity_processing import get_unique_entities, get_entity_lookup, convert_entitynames, flip_headtail

# %% [markdown]
# # 1) Load Data

# %%
### 1) Read: This section reads DRKG and a glossary (used to map entities from codes to words)
DATA_DIR           = os.path.join("data")
verbose            =  True 
triplets,drkg_df   =  get_triplets(drkg_file = os.path.join(DATA_DIR  ,'drkg.tsv'),             verbose=verbose)  # Read triplets (head,relationship,tail)
relation_glossary  =  read_tsv(relation_file = os.path.join(DATA_DIR  ,'relation_glossary.tsv'),verbose=verbose)  # Read relationship mapping  


### 2) Filter & Map Interactions: This section returns a list of interactions e.g. DRUGBANK::treats::Compound:Disease )
# 2.1: First  we filter the interactions to only Compound-Disease
# 2.2: Then   we map the codes -> text  (this will be use to further filter interactions based on text) e.g.  Hetionet::CpD::Compound:Disease -> palliation
# 2.3: We use natural text to fitler  interactions based on terms such as "treat" (but we return the orignal interaction name )



# modularize this in create_dataframe
drkg_rx_dx_relations        = filter_drkg(data_frame = drkg_df ,  filter_column = 1 ,  filter_term = r'.*?Compound:Disease', verbose = verbose) # 2.1 Filter only Compound-Disease Interactions
drkg_rx_dx_relations_mapped = map_drkg_relationships(drkg_rx_dx_relations,relation_glossary,verbose=verbose)                                    # 2.2 Map codes to text 

### 2.3 Filter Drug interactions Interaction types to only include: treat inhibit or alleviate interactions  ###
drkg_rx_dx_relation_subset =  filter_interaction_subset(df                  = drkg_rx_dx_relations_mapped,
                                                        filter_colunm_name = 'Interaction-type' ,
                                                        regex_string       =  'treat|inhibit|alleviate',
                                                        return_colunm_name =  'Relation-name')

# 3) Use Filter Interactions to get Gilter DRKG 
drkg_df_filtered = drkg_df[drkg_df[1].isin(drkg_rx_dx_relation_subset)] # 3.1 Filter DRKG  to only  Compund-Disease 
print_head(df=drkg_df_filtered)



###

rx_dx_triplets   = drkg_df_filtered.values.tolist()                     # 3.2 Convert filtered DRKG to list
# Out:
#  Triplets:
#
# [['Gene::2157', 'bioarx::HumGenHumGen:Gene:Gene', 'Gene::2157'], ['Gene::2157', 'bioarx::HumGenHumGen:Gene:Gene', 'Gene::5264'], ['Gene::2157', 'bioarx::HumGenHumGen:Gene:Gene', 'Gene::2158'], ['Gene::2157', 'bioarx::HumGenHumGen:Gene:Gene', 'Gene::3309'], ['Gene::2157', 'bioarx::HumGenHumGen:Gene:Gene', 'Gene::28912'], ['Gene::2157', 'bioarx::HumGenHumGen:Gene:Gene', 'Gene::811'], ['Gene::2157', 'bioarx::HumGenHumGen:Gene:Gene', 'Gene::2159'], ['Gene::2157', 'bioarx::HumGenHumGen:Gene:Gene', 'Gene::821'], ['Gene::2157', 'bioarx::HumGenHumGen:Gene:Gene', 'Gene::5627'], ['Gene::2157', 'bioarx::HumGenHumGen:Gene:Gene', 'Gene::5624']]
#
#  data/drkg.tsv  Dataframe:
#
# +----+------------+--------------------------------+-------------+
# |    | 0          | 1                              | 2           |
# |----+------------+--------------------------------+-------------|
# |  0 | Gene::2157 | bioarx::HumGenHumGen:Gene:Gene | Gene::2157  |
# |  1 | Gene::2157 | bioarx::HumGenHumGen:Gene:Gene | Gene::5264  |
# |  2 | Gene::2157 | bioarx::HumGenHumGen:Gene:Gene | Gene::2158  |
# |  3 | Gene::2157 | bioarx::HumGenHumGen:Gene:Gene | Gene::3309  |
# |  4 | Gene::2157 | bioarx::HumGenHumGen:Gene:Gene | Gene::28912 |
# +----+------------+--------------------------------+-------------+
#
#  data/relation_glossary.tsv  Dataframe:
#
# +----+--------------------------------------------+---------------+--------------------------+-----------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------------------------+
# |    | Relation-name                              | Data-source   | Connected entity-types   | Interaction-type      | Description                                                                                                                                                                     | Reference for the description        |
# |----+--------------------------------------------+---------------+--------------------------+-----------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------------------------|
# |  0 | DGIDB::ACTIVATOR::Gene:Compound            | DGIDB         | Compound:Gene            | activation            | An activator interaction is when a drug activates a biological response from a target, although the mechanism by which it does so may not be understood.                        | http://www.dgidb.org/getting_started |
# |  1 | DGIDB::AGONIST::Gene:Compound              | DGIDB         | Compound:Gene            | agonism               | An agonist interaction occurs when a drug binds to a target receptor and activates the receptor to produce a biological response.                                               | http://www.dgidb.org/getting_started |
# |  2 | DGIDB::ALLOSTERIC MODULATOR::Gene:Compound | DGIDB         | Compound:Gene            | allosteric modulation | An allosteric modulator interaction occurs when drugs exert their effects on their protein targets via a different binding site than the natural (orthosteric) ligand site.     | http://www.dgidb.org/getting_started |
# |  3 | DGIDB::ANTAGONIST::Gene:Compound           | DGIDB         | Compound:Gene            | antagonism            | An antagonist interaction occurs when a drug blocks or dampens agonist-mediated responses rather than provoking a biological response itself upon binding to a target receptor. | http://www.dgidb.org/getting_started |
# |  4 | DGIDB::ANTIBODY::Gene:Compound             | DGIDB         | Compound:Gene            | antibody              | An antibody interaction occurs when an antibody drug specifically binds the target molecule.                                                                                    | http://www.dgidb.org/getting_started |
# +----+--------------------------------------------+---------------+--------------------------+-----------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------------------------+
# Number of Rows Before Filtering: 107
# Number of Rows After Filtering: 10
#
#
# Filtered:
# 24    DRUGBANK::treats::Compound:Disease
# 35             GNBR::T::Compound:Disease
# 36             GNBR::C::Compound:Disease
# 37            GNBR::Sa::Compound:Disease
# 38            GNBR::Pa::Compound:Disease
# 39            GNBR::Mp::Compound:Disease
# 40            GNBR::Pr::Compound:Disease
# 41             GNBR::J::Compound:Disease
# 68       Hetionet::CtD::Compound:Disease
# 73       Hetionet::CpD::Compound:Disease
# dtype: object
#
# Relationships Mapped:
# 0                    Compound treats the disease
# 1    treatment/therapy (including investigatory)
# 2            inhibits cell growth (esp. cancers)
# 3                      side effect/adverse event
# 4                            alleviates, reduces
# 5            biomarkers (of disease progression)
# 6                           prevents, suppresses
# 7                   role in disease pathogenesis
# 8                                      treatment
# 9                                     palliation
# Name: Interaction-type, dtype: object
# +---------+-------------------+------------------------------------+-----------------------+
# |         | 0                 | 1                                  | 2                     |
# |---------+-------------------+------------------------------------+-----------------------|
# | 1518268 | Compound::DB00003 | DRUGBANK::treats::Compound:Disease | Disease::MESH:D003550 |
# | 1518269 | Compound::DB00004 | DRUGBANK::treats::Compound:Disease | Disease::MESH:C063419 |
# | 1518270 | Compound::DB00005 | DRUGBANK::treats::Compound:Disease | Disease::MESH:D013167 |
# | 1518271 | Compound::DB00005 | DRUGBANK::treats::Compound:Disease | Disease::MESH:D006086 |
# | 1518272 | Compound::DB00005 | DRUGBANK::treats::Compound:Disease | Disease::MESH:D017497 |
# +---------+-------------------+------------------------------------+-----------------------+

# %%
# 4) Load Data frames for translation
hetionet_df, gene_df, drugbank_df, omim_df, mesh_dict, chebi_df, chembl_df = load_lookups(data_path=DATA_DIR,verbose=verbose)
# Out:
#  data/hetionet-v1.0-nodes.tsv  Dataframe:
#
# +----+-------------------------+---------------------------+---------+
# |    | id                      | name                      | kind    |
# |----+-------------------------+---------------------------+---------|
# |  0 | Anatomy::UBERON:0000002 | uterine cervix            | Anatomy |
# |  1 | Anatomy::UBERON:0000004 | nose                      | Anatomy |
# |  2 | Anatomy::UBERON:0000006 | islet of Langerhans       | Anatomy |
# |  3 | Anatomy::UBERON:0000007 | pituitary gland           | Anatomy |
# |  4 | Anatomy::UBERON:0000010 | peripheral nervous system | Anatomy |
# +----+-------------------------+---------------------------+---------+
#
#  Sample of Hetionet Data Types (Before processing):
#
# +-------+----------------------------------+-------------------------------------------+---------------------+
# |       | id                               | name                                      | kind                |
# |-------+----------------------------------+-------------------------------------------+---------------------|
# |     0 | Anatomy::UBERON:0000002          | uterine cervix                            | Anatomy             |
# |   402 | Biological Process::GO:0000002   | mitochondrial genome maintenance          | Biological Process  |
# | 11783 | Cellular Component::GO:0000015   | phosphopyruvate hydratase complex         | Cellular Component  |
# | 13174 | Compound::DB00014                | Goserelin                                 | Compound            |
# | 14726 | Disease::DOID:0050156            | idiopathic pulmonary fibrosis             | Disease             |
# | 14863 | Gene::1                          | A1BG                                      | Gene                |
# | 35808 | Molecular Function::GO:0000010   | trans-hexaprenyltranstransferase activity | Molecular Function  |
# | 38692 | Pathway::PC7_10399               | a4b7 Integrin signaling                   | Pathway             |
# | 40514 | Pharmacologic Class::N0000000069 | Calcium Channel Antagonists               | Pharmacologic Class |
# | 40859 | Side Effect::C0000727            | Acute abdomen                             | Side Effect         |
# | 46593 | Symptom::D000006                 | Abdomen, Acute                            | Symptom             |
# +-------+----------------------------------+-------------------------------------------+---------------------+
#
#  Sample of Hetionet Data Types (After processing):
#
# +-------+----------------------------------+-------------------------------------------+---------------------+
# |       | id                               | name                                      | kind                |
# |-------+----------------------------------+-------------------------------------------+---------------------|
# |     0 | Anatomy::UBERON:0000002          | uterine cervix                            | Anatomy             |
# |   402 | Biological Process::GO:0000002   | mitochondrial genome maintenance          | Biological Process  |
# | 11783 | Cellular Component::GO:0000015   | phosphopyruvate hydratase complex         | Cellular Component  |
# | 13174 | Compound::DB00014                | Goserelin                                 | Compound            |
# | 14726 | Disease::DOID:0050156            | idiopathic pulmonary fibrosis             | Disease             |
# | 14863 | Gene::1                          | A1BG gene                                 | Gene                |
# | 35808 | Molecular Function::GO:0000010   | trans-hexaprenyltranstransferase activity | Molecular Function  |
# | 38692 | Pathway::PC7_10399               | a4b7 Integrin signaling                   | Pathway             |
# | 40514 | Pharmacologic Class::N0000000069 | Calcium Channel Antagonists               | Pharmacologic Class |
# | 40859 | Side Effect::C0000727            | Acute abdomen                             | Side Effect         |
# | 46593 | Symptom::D000006                 | Abdomen, Acute                            | Symptom             |
# +-------+----------------------------------+-------------------------------------------+---------------------+
#
#  Gene ID Dataframe (After processing):
#
# +----+----------+--------------------------------------------+
# |    | GeneID   | description                                |
# |----+----------+--------------------------------------------|
# |  0 | Gene::1  | alpha-1-B glycoprotein (A1BG)              |
# |  1 | Gene::2  | alpha-2-macroglobulin (A2M)                |
# |  2 | Gene::3  | alpha-2-macroglobulin pseudogene 1 (A2MP1) |
# |  3 | Gene::9  | N-acetyltransferase 1 (NAT1)               |
# |  4 | Gene::10 | N-acetyltransferase 2 (NAT2)               |
# +----+----------+--------------------------------------------+
#
#  DrugBank Dataframe (Before processing):
#
# +----+---------------+----------------------+---------------------+-------------+------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------+
# |    | DrugBank ID   | Accession Numbers    | Common name         | CAS         | UNII       | Synonyms                                                                                                                                                              |   Standard InChI Key |
# |----+---------------+----------------------+---------------------+-------------+------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------|
# |  0 | DB00001       | BIOD00024 | BTD00024 | Lepirudin           | 138068-37-8 | Y43GF64R34 | [Leu1, Thr2]-63-desulfohirudin | Desulfatohirudin | Hirudin variant-1 | Lepirudin | Lepirudin recombinant | R-hirudin                                                 |                  nan |
# |  1 | DB00002       | BIOD00071 | BTD00071 | Cetuximab           | 205923-56-4 | PQX0D8J21J | Cetuximab | Cétuximab | Cetuximabum                                                                                                                                   |                  nan |
# |  2 | DB00003       | BIOD00001 | BTD00001 | Dornase alfa        | 143831-71-4 | 953A26OA1Y | Deoxyribonuclease (human clone 18-1 protein moiety) | Dornasa alfa | Dornase alfa | Dornase alfa, recombinant | Dornase alpha | Recombinant deoxyribonuclease (DNAse) |                  nan |
# |  3 | DB00004       | BIOD00084 | BTD00084 | Denileukin diftitox | 173146-27-5 | 25E79B5CTM | Denileukin | Denileukin diftitox | Interleukin-2/diptheria toxin fusion protein                                                                                       |                  nan |
# |  4 | DB00005       | BIOD00052 | BTD00052 | Etanercept          | 185243-69-0 | OP401G7OJC | Etanercept | etanercept-szzs | etanercept-ykro | Recombinant human TNF | rhu TNFR:Fc | rhu-TNFR:Fc | TNFR-Immunoadhesin                                               |                  nan |
# +----+---------------+----------------------+---------------------+-------------+------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------+
#
#  DrugBank Dataframe (After processing):
#
# +----+-------------------+---------------------+
# |    | DrugBank ID       | Common name         |
# |----+-------------------+---------------------|
# |  0 | Compound::DB00001 | Lepirudin           |
# |  1 | Compound::DB00002 | Cetuximab           |
# |  2 | Compound::DB00003 | Dornase alfa        |
# |  3 | Compound::DB00004 | Denileukin diftitox |
# |  4 | Compound::DB00005 | Etanercept          |
# +----+-------------------+---------------------+
#
#  data/mimTitles.txt  Dataframe (Before processing):
#
# +----+----------------------+----------------------------------------+
# |    | MIM Number           | name                                   |
# |----+----------------------+----------------------------------------|
# |  0 | Disease::OMIM:100050 | AARSKOG SYNDROME, AUTOSOMAL DOMINANT   |
# |  1 | Disease::OMIM:100070 | AORTIC ANEURYSM, FAMILIAL ABDOMINAL, 1 |
# |  2 | Disease::OMIM:100100 | PRUNE BELLY SYNDROME                   |
# |  3 | Disease::OMIM:100200 | ABDUCENS PALSY                         |
# |  4 | Disease::OMIM:100300 | ADAMS-OLIVER SYNDROME 1                |
# +----+----------------------+----------------------------------------+
#
#  data/mimTitles.txt  Dataframe (After processing):
#
# +----+----------------------+----------------------------------------+
# |    | MIM Number           | name                                   |
# |----+----------------------+----------------------------------------|
# |  0 | Disease::OMIM:100050 | AARSKOG SYNDROME, AUTOSOMAL DOMINANT   |
# |  1 | Disease::OMIM:100070 | AORTIC ANEURYSM, FAMILIAL ABDOMINAL, 1 |
# |  2 | Disease::OMIM:100100 | PRUNE BELLY SYNDROME                   |
# |  3 | Disease::OMIM:100200 | ABDUCENS PALSY                         |
# |  4 | Disease::OMIM:100300 | ADAMS-OLIVER SYNDROME 1                |
# +----+----------------------+----------------------------------------+
#
#  MeSH Dictionary:
#
# +---------------+------------------------+
# |               | 0                      |
# |---------------+------------------------|
# | MESH::D000001 | Calcimycin             |
# | MESH::D000002 | Temefos                |
# | MESH::D000003 | Abattoirs              |
# | MESH::D000004 | Abbreviations as Topic |
# | MESH::D000005 | Abdomen                |
# +---------------+------------------------+

# %%
# Make dictionaries for relations and codes
relation_glossary_relation_dict = pd.Series(relation_glossary['Interaction-type'].values, index=relation_glossary['Relation-name']).to_dict()

code_df   = pd.concat([hetionet_df[['name', 'id']], 
                       gene_df.rename(columns = {"description":"name", "GeneID":"id"}),
                       drugbank_df.rename(columns = {"Common name":"name", "DrugBank ID":"id"}),
                       omim_df.rename(columns = {"MIM Number":"id"}),
                       chebi_df.rename(columns = {"NAME":"name", "CHEBI_ACCESSION":"id"}),
                       chembl_df.rename(columns = {"pref_name":"name", "chembl_id":"id"})
                       ], ignore_index=True, axis=0).drop_duplicates() 
code_dict = pd.Series(code_df['name'].values, index=code_df['id']).to_dict() | mesh_dict # Convert node df to dict and merge with MeSH dictionary

# Get unique DRKG entities
drkg_entities = get_unique_entities(drkg_df, [0,2])

# Create and use convert_entitynames function
drkg_entity_df, drkg_unmatched = get_entity_lookup(drkg_entities, code_dict)

# Create final node dictionary
node_dict = pd.Series(drkg_entity_df['name'].values, index=drkg_entity_df['drkg_id']).to_dict() 

# Map DRKG to translated entity names
drkg_translated    = drkg_df.copy()
drkg_translated = convert_entitynames(drkg_translated, 0, node_dict)
drkg_translated = convert_entitynames(drkg_translated, 2, node_dict)
drkg_translated = drkg_translated.dropna()
print_head(drkg_translated) 

# Summarize percentage translated
print("Number of unique DRKG entities: ", len(drkg_entities)) # should be 97238
print("Number of translated entities: ", drkg_entity_df.shape[0])
print("Number of untranslated entities: ", drkg_unmatched.shape[0])
pct_entity_translated = drkg_entity_df.shape[0]/len(drkg_entities)
print('Percentage of entities translated: ', round(pct_entity_translated*100,1), '%')

print('Total DRKG relationships: ', drkg_df.shape[0])
print('Translated DRKG relationships: ', drkg_translated.shape[0])
pct_translated = drkg_translated.shape[0]/drkg_df.shape[0]
print('Percentage of relationships fully translated: ', round(pct_translated*100,1), '%')
# Out:
# +----+------------------------------+--------------------------------+------------------------------------------------------+
# |    | 0                            | 1                              | 2                                                    |
# |----+------------------------------+--------------------------------+------------------------------------------------------|
# |  0 | coagulation factor VIII (F8) | bioarx::HumGenHumGen:Gene:Gene | coagulation factor VIII (F8)                         |
# |  1 | coagulation factor VIII (F8) | bioarx::HumGenHumGen:Gene:Gene | phytanoyl-CoA 2-hydroxylase (PHYH)                   |
# |  2 | coagulation factor VIII (F8) | bioarx::HumGenHumGen:Gene:Gene | coagulation factor IX (F9)                           |
# |  3 | coagulation factor VIII (F8) | bioarx::HumGenHumGen:Gene:Gene | heat shock protein family A (Hsp70) member 5 (HSPA5) |
# |  4 | coagulation factor VIII (F8) | bioarx::HumGenHumGen:Gene:Gene | immunoglobulin kappa variable 3-20 (IGKV3-20)        |
# +----+------------------------------+--------------------------------+------------------------------------------------------+
# Number of unique DRKG entities:  97238
# Number of translated entities:  64033
# Number of untranslated entities:  33205
# Percentage of entities translated:  65.9 %
# Total DRKG relationships:  5874261
# Translated DRKG relationships:  5705613
# Percentage of relationships fully translated:  97.1 %

# %%
# Filter DRKG in natural language to drug-treats-disease relationships
rx_dx        =  drkg_translated[drkg_translated[1].isin(drkg_rx_dx_relation_subset)]
rx_dx_subset =  rx_dx[0:10]
rx_dx_subset
# Out:
#                            0                            1
# 1518268         Dornase alfa  Compound treats the disease  \
# 1518269  Denileukin diftitox  Compound treats the disease
# 1518270           Etanercept  Compound treats the disease
# 1518271           Etanercept  Compound treats the disease
# 1518272           Etanercept  Compound treats the disease
# 1518273           Etanercept  Compound treats the disease
# 1518274           Etanercept  Compound treats the disease
# 1518275           Etanercept  Compound treats the disease
# 1518276           Etanercept  Compound treats the disease
# 1518277           Etanercept  Compound treats the disease
#
#                                 2
# 1518268           Cystic Fibrosis
# 1518269             MESH::C063419
# 1518270   Spondylitis, Ankylosing
# 1518271     Graft vs Host Disease
# 1518272  Hidradenitis Suppurativa
# 1518273       Arthritis, Juvenile
# 1518274                 Psoriasis
# 1518275      Arthritis, Psoriatic
# 1518276      Pyoderma Gangrenosum
# 1518277     Arthritis, Rheumatoid

# %%
# Check unique values of untranslated
# drkg_test1 = np.unique(remove_untranslated[0][remove_untranslated[0].str.contains('::')])
# drkg_test2 = np.unique(remove_untranslated[2][remove_untranslated[2].str.contains('::')])

# drkg_mesh_list = drkg_test1.tolist() +  drkg_test2.tolist()
# drkg_mesh_unique = pd.DataFrame(pd.unique(drkg_mesh_list))
# drkg_mesh_unique
# Out:
#                                0
# 0       Compound::Bioarxivdrug:0
# 1       Compound::Bioarxivdrug:1
# 2      Compound::Bioarxivdrug:10
# 3      Compound::Bioarxivdrug:11
# 4       Compound::Bioarxivdrug:2
# ...                          ...
# 14416              MESH::C580539
# 14417              MESH::C585640
# 14418              MESH::D000071
# 14419              MESH::D018290
# 14420              MESH::D019952
#
# [14421 rows x 1 columns]

# %%
drkg_untranslated = drkg_unmatched.copy()
drkg_untranslated = drkg_untranslated[drkg_untranslated[0].str.startswith('MESH::')]
print(len(drkg_untranslated))
drkg_untranslated
# Out:
# 7751
#                    0
# 1429   MESH::C000020
# 1430   MESH::C000050
# 1431   MESH::C000121
# 1432   MESH::C000154
# 1433   MESH::C000188
# ...              ...
# 14416  MESH::C580539
# 14417  MESH::C585640
# 14418  MESH::D000071
# 14419  MESH::D018290
# 14420  MESH::D019952
#
# [7751 rows x 1 columns]

# %% [markdown]
# # 3) BioLinkBERT embedding

# %%
rx_dx_subset
# Out:
#                            0                            1
# 1518268         Dornase alfa  Compound treats the disease  \
# 1518269  Denileukin diftitox  Compound treats the disease
# 1518270           Etanercept  Compound treats the disease
# 1518271           Etanercept  Compound treats the disease
# 1518272           Etanercept  Compound treats the disease
# 1518273           Etanercept  Compound treats the disease
# 1518274           Etanercept  Compound treats the disease
# 1518275           Etanercept  Compound treats the disease
# 1518276           Etanercept  Compound treats the disease
# 1518277           Etanercept  Compound treats the disease
#
#                                 2
# 1518268           Cystic Fibrosis
# 1518269             MESH::C063419
# 1518270   Spondylitis, Ankylosing
# 1518271     Graft vs Host Disease
# 1518272  Hidradenitis Suppurativa
# 1518273       Arthritis, Juvenile
# 1518274                 Psoriasis
# 1518275      Arthritis, Psoriatic
# 1518276      Pyoderma Gangrenosum
# 1518277     Arthritis, Rheumatoid

# %%
from torch_geometric.data import HeteroData
from SIMP_LLM.llm_encode import EntityEncoder
from SIMP_LLM.dataloader_mappings import create_mapping,create_edges


## Example of loading data without anything to encode
device    = "cpu"
Encoder  = EntityEncoder(device = device )


### DX RX Relationship ###
rx_X,rx_mapping = create_mapping(rx_dx_subset[0].to_list(),encoder= Encoder ,device=device) # Maps drugs to indices
dx_X,dx_mapping = create_mapping(rx_dx_subset[2].to_list(),encoder= Encoder ,device=device) # Maps drugs to indices
## As of now this only encodes 'Compound treats the disease', but  the idea is that this is used to encode every entity 
relationship_X,relationship_mapping = create_mapping(rx_dx_subset[1].to_list(),encoder= Encoder ,device=device)  

print(f"Unique Drugs:   {len(rx_mapping)} Matrix shape: {rx_X.shape}")
print(f"Unique Disases: {len(dx_mapping)} Matrix shape: {dx_X.shape }")
relationship_feature = relationship_X[relationship_mapping['Compound treats the disease'],:].reshape(1,-1)


## NEED To add other reationships
# Out:
# Unique Drugs:   3 Matrix shape: torch.Size([3, 768])
# Unique Disases: 10 Matrix shape: torch.Size([10, 768])

# %% [markdown]
# ### Build HeteroData Object

# %%
### Create PyG Hetero Graph:
data = HeteroData()
data['compounds'].x = rx_X
data['disease'].x   = dx_X
print(data)

Edge_index,edge_attribute = create_edges(df             =  rx_dx_subset,
                                          src_index_col  = 0, 
                                          src_mapping    = rx_mapping , 
                                          dst_index_col  = 2, 
                                          dst_mapping    = dx_mapping ,
                                          edge_attr      = relationship_feature)

data['compounds', 'Compound treats the disease', 'disease'].edge_index = Edge_index
data['compounds', 'Compound treats the disease', 'disease'].edge_label = edge_attribute
# Out:
# HeteroData(
#   compounds={ x=[3, 768] },
#   disease={ x=[10, 768] }
# )

# %% [markdown]
# ## TEST/DEVELOPER - code to create entity lookup table

# %%
# Create table of unique DRKG entities
# def get_unique_entities(df:pd.core.frame.DataFrame, columns):
#   '''Append all unique entries in specified list of columns in dataframe and get unique entities
#   '''
#   entity_list = []
#   for col in columns:
#     entity_list = np.append(entity_list, df[col])
#   entity_list = np.unique(entity_list)
#   return entity_list

drkg_entities = get_unique_entities(drkg_df, [0,2])

print(len(drkg_entities)) # should be 97238
# Out:
# 97238

# %%
# Create lookup table for unique DRKG entities
# def get_entity_lookup(drkg_entities, node_dict):
#     '''Converts list of unique DRKG entities to entity table with the following items, using the lookup table dictionary node_dict:
#         'drkg_id':       original entity code in DRKG
#         'drkg_dict_id':  original entity code, except with entity name in MeSH entity codes removed to match with MeSH lookup format
#         'name':          natural language entity name, translated using node_dict dictionary
#         'entity_type':   type of entity (gene, disease, compound, etc.), taken from drkg_id
#         'ontology_code': combined ontology name and code, taken by removing entity_type from drkg_id
#         'ontology_name': name of ontology from which code was sourced, if available
#         'code':          specific code or ID from the ontology

#     Also does the following cleaning:
#     * Manual processing of entity and ontology names where the name or source was inferred from the code/ID
#     * Remove irrelevant entries (taxonomy and entries with only an entity type but no associated code such as "Gene::")
#     * Remove entities with no name and return them as a separate dataframe
#     '''
#     drkg_entity_df = pd.DataFrame(drkg_entities, columns=['drkg_id'])

#     # Create copy of DRKG ID value that simplifies MeSH codes
#     drkg_entity_df['drkg_dict_id'] = drkg_entity_df['drkg_id'].str.replace(r'.*?MESH:', "MESH::", regex=True)

#     # Map entity natural language name
#     drkg_entity_df['name'] = drkg_entity_df['drkg_dict_id'].map(node_dict)

#     # Get ontology name and code if available
#     drkg_entity_df[['entity_type', 'ontology_code']] = drkg_entity_df['drkg_id'].str.split("::", expand=True)
#     drkg_entity_df['ontology_name'] = drkg_entity_df['ontology_code'].str.split(":", n=2, expand=True)[0]
#     drkg_entity_df['code'] = drkg_entity_df['ontology_code'].str.split(":", n=2, expand=True)[1]

#     ###### Cleaning ######
#     # Move codes without ontology names to correct column
#     drkg_entity_df.loc[drkg_entity_df['ontology_name'] == drkg_entity_df['ontology_code'], 'ontology_name'] = None
#     drkg_entity_df.loc[drkg_entity_df['code'].isna(), 'code'] = drkg_entity_df['ontology_code']

#     # Add name for entries with SARS-CoV code
#     drkg_entity_df.loc[drkg_entity_df['code'].str.startswith('SARS-CoV2'), 'name'] = drkg_entity_df['code']

#     # Manually correct specific ontology names without ':' as ontology-code divider
#     drkg_entity_df.loc[drkg_entity_df['ontology_code'].str.startswith('CHEMBL'), 'ontology_name'] = 'CHEMBL'
#     drkg_entity_df.loc[drkg_entity_df['entity_type'] == 'Atc', 'ontology_name'] = 'Atc'
#     drkg_entity_df.loc[(drkg_entity_df['entity_type'] == 'Compound') & (drkg_entity_df['ontology_code'].str.startswith('DB')), 'ontology_name'] = 'drugbank'
#     drkg_entity_df.loc[(drkg_entity_df['entity_type'] == 'Side Effect') & (drkg_entity_df['ontology_code'].str.len() == 8), 'ontology_name'] = 'UMLS CUI'
#     drkg_entity_df.loc[(drkg_entity_df['entity_type'] == 'Symptom') & (drkg_entity_df['ontology_code'].str.len() == 7), 'ontology_name'] = 'MESH'

#     # Remove entities that are irrelevant or without name (save for downstream analysis)
#     drkg_unmatched = drkg_entity_df[(drkg_entity_df['name'].isna()) | 
#                                     (drkg_entity_df['entity_type'] == 'Tax') |
#                                     (drkg_entity_df['ontology_code'].isna())] # ontology_code filter is redundant to name filter, but keeping in case we need this subset later
#     drkg_entity_df = drkg_entity_df[~drkg_entity_df.index.isin(drkg_unmatched.index)]

#     return drkg_entity_df, drkg_unmatched 

drkg_entity_df, drkg_unmatched = get_entity_lookup(drkg_entities, node_dict)
print(drkg_entity_df.shape[0], drkg_unmatched.shape[0])
# 64033 entities were translated, 33205 untranslated
# Out:
# 64033 33205

# %%
# Translate entities
# def convert_entitynames(df, col, node_dict):
#   """Convert entity codes to names in specified column based on dictionary"""
#   df_update = df.copy()
#   df_update[col] = df_update[col].map(node_dict)    # Translate dictionary, dont replace NAs
#   return df_update

node_dict2 = pd.Series(drkg_entity_df['name'].values, index=drkg_entity_df['drkg_id']).to_dict() 

# Create and use convert_entitynames function
# def convert_entitynames2(df, col, node_dict):
#   df_update = df.copy()
#   df_update[col] = df_update[col].map(node_dict)    # Translate dictionary, dont replace NAs
#   return df_update


df_med2    = drkg_df.copy()
df_med2 = convert_entitynames(df_med2, 0, node_dict2)
df_med2 = convert_entitynames(df_med2, 2, node_dict2)
df_med_translate = df_med2.dropna()

# %%
drkg_entity_df[drkg_entity_df['drkg_id'] == 'Compound::molport:MolPort-046-762-962']
# Out:
# Empty DataFrame
# Columns: [drkg_id, drkg_dict_id, name, entity_type, ontology_code, ontology_name, code]
# Index: []

# %%
# Check for NAs
df_med2[df_med2[0].isna() |df_med2[2].isna()]
# df_med_translate[df_med_translate[0].isna() |df_med_translate[2].isna()]

# df_med_translate[df_med_translate[0].str.contains("::")]
# node_dict2['Compound::molport:MolPort-046-762-962']
# Out:
#                                                          0
# 724      calcium/calmodulin dependent serine protein ki...  \
# 879      heat shock protein family A (Hsp70) member 8 (...
# 1032              glucagon like peptide 1 receptor (GLP1R)
# 3183                         casein kinase 2 beta (CSNK2B)
# 3582         growth factor receptor bound protein 2 (GRB2)
# ...                                                    ...
# 4312604                             synaptotagmin 5 (SYT5)
# 4321477                                        ezrin (EZR)
# 4357923  IQ motif containing GTPase activating protein ...
# 4365678                      PDZ and LIM domain 7 (PDLIM7)
# 4370343  BCAR1 scaffold protein, Cas family member (BCAR1)
#
#                                       1    2
# 724      bioarx::HumGenHumGen:Gene:Gene  NaN
# 879      bioarx::HumGenHumGen:Gene:Gene  NaN
# 1032     bioarx::HumGenHumGen:Gene:Gene  NaN
# 3183     bioarx::HumGenHumGen:Gene:Gene  NaN
# 3582     bioarx::HumGenHumGen:Gene:Gene  NaN
# ...                                 ...  ...
# 4312604  INTACT::ASSOCIATION::Gene:Gene  NaN
# 4321477  INTACT::ASSOCIATION::Gene:Gene  NaN
# 4357923  INTACT::ASSOCIATION::Gene:Gene  NaN
# 4365678  INTACT::ASSOCIATION::Gene:Gene  NaN
# 4370343  INTACT::ASSOCIATION::Gene:Gene  NaN
#
# [168648 rows x 3 columns]

# %%
print(df_med_translate.shape[0])
print(drkg_df.shape[0])
# Out:
# 5705613
# 5874261

# %%
# Summarize percentage translated
pct_translated = df_med_translate.shape[0]/drkg_df.shape[0]
print('Percentage of relationships fully translated: ', round(pct_translated*100,1), '%')

pct_translated_notax = df_med_translate.shape[0]/drkg_df[(drkg_df[2].str.startswith('Tax') == False) & (drkg_df[0] != 'Gene::')].shape[0]
print('Percentage of relationships fully translated (excluding taxonomy and missing gene code): ', round(pct_translated_notax*100,1), '%')
# Out:
# Percentage of relationships fully translated:  97.1 %
# Percentage of relationships fully translated (excluding taxonomy and missing gene code):  97.4 %

# %%
# Look at entity types in dataframe
drkg_entity_df.drop_duplicates(subset=['entity_type', 'ontology_name'])
# Out:
#                                 drkg_id                      drkg_dict_id
# 0               Anatomy::UBERON:0000002           Anatomy::UBERON:0000002  \
# 4448     Biological Process::GO:0000002    Biological Process::GO:0000002
# 15829    Cellular Component::GO:0000015    Cellular Component::GO:0000015
# 17232             Compound::CHEBI:10057             Compound::CHEBI:10057
# 18295                Compound::CHEMBL10                Compound::CHEMBL10
# 21960                 Compound::DB00001                 Compound::DB00001
# 38906            Compound::MESH:D000001                     MESH::D000001
# 41533             Disease::DOID:0050156             Disease::DOID:0050156
# 43010             Disease::MESH:D000007                     MESH::D000007
# 46531              Disease::OMIM:102510              Disease::OMIM:102510
# 46609              Disease::SARS-CoV2 E              Disease::SARS-CoV2 E
# 46637                           Gene::1                           Gene::1
# 85856    Molecular Function::GO:0000010    Molecular Function::GO:0000010
# 88740                Pathway::PC7_10399                Pathway::PC7_10399
# 90562  Pharmacologic Class::N0000000069  Pharmacologic Class::N0000000069
# 90907             Side Effect::C0000727             Side Effect::C0000727
# 96608                  Symptom::D000006                  Symptom::D000006
#
#                                             name          entity_type
# 0                                 uterine cervix              Anatomy  \
# 4448            mitochondrial genome maintenance   Biological Process
# 15829          phosphopyruvate hydratase complex   Cellular Component
# 17232                                9H-xanthene             Compound
# 18295                                  SB-203580             Compound
# 21960                                  Lepirudin             Compound
# 38906                                 Calcimycin             Compound
# 41533              idiopathic pulmonary fibrosis              Disease
# 43010                         Abdominal Injuries              Disease
# 46531             ACROPECTOROVERTEBRAL DYSPLASIA              Disease
# 46609                                SARS-CoV2 E              Disease
# 46637              alpha-1-B glycoprotein (A1BG)                 Gene
# 85856  trans-hexaprenyltranstransferase activity   Molecular Function
# 88740                    a4b7 Integrin signaling              Pathway
# 90562                Calcium Channel Antagonists  Pharmacologic Class
# 90907                              Acute abdomen          Side Effect
# 96608                             Abdomen, Acute              Symptom
#
#         ontology_code ontology_name         code
# 0      UBERON:0000002        UBERON      0000002
# 4448       GO:0000002            GO      0000002
# 15829      GO:0000015            GO      0000015
# 17232     CHEBI:10057         CHEBI        10057
# 18295        CHEMBL10        CHEMBL     CHEMBL10
# 21960         DB00001      drugbank      DB00001
# 38906    MESH:D000001          MESH      D000001
# 41533    DOID:0050156          DOID      0050156
# 43010    MESH:D000007          MESH      D000007
# 46531     OMIM:102510          OMIM       102510
# 46609     SARS-CoV2 E          None  SARS-CoV2 E
# 46637               1          None            1
# 85856      GO:0000010            GO      0000010
# 88740       PC7_10399          None    PC7_10399
# 90562     N0000000069          None  N0000000069
# 90907        C0000727      UMLS CUI     C0000727
# 96608         D000006          MESH      D000006

# %%
# Counts for matched entity types
drkg_entity_df.groupby(by=['entity_type', 'ontology_name'], dropna=False).agg(
    count = ('code', 'count')#.sort_values(by='count')
)
# Out:
#                                    count
# entity_type         ontology_name
# Anatomy             UBERON           400
# Biological Process  GO             11381
# Cellular Component  GO              1391
# Compound            CHEBI           1060
#                     CHEMBL          2463
#                     MESH            1224
#                     drugbank       10546
# Disease             DOID             127
#                     MESH            3518
#                     OMIM              78
#                     NaN               27
# Gene                NaN            20651
# Molecular Function  GO              2884
# Pathway             NaN             1822
# Pharmacologic Class NaN              345
# Side Effect         UMLS CUI        5701
# Symptom             MESH             415

# %%
# Comparison of new and old gene IDs - old version had slightly more matches
gene_df_raw       =  read_tsv( os.path.join(DATA_DIR,'symbols-human.tsv'),verbose=verbose)     # Read and process Gene IDs
df_updated = gene_df_raw[gene_df_raw['type']=='symbol'].drop_duplicates(subset='GeneID').copy()
df_updated['symbol'] = df_updated['symbol'].astype(str) + ' gene'
df_updated['GeneID'] = "Gene::" + df_updated['GeneID'].astype(str)
df_updated = df_updated.drop(columns=['type'])

gene_df_updated = df_updated.merge(gene_df, how='outer', on='GeneID')
print(len(gene_df_updated[gene_df_updated['symbol'].isna()]))
print(len(gene_df_updated[gene_df_updated['description'].isna()]))
# Out:
#  data/symbols-human.tsv  Dataframe:
#
# +----+----------+---------+----------+
# |    |   GeneID | type    | symbol   |
# |----+----------+---------+----------|
# |  0 |        1 | symbol  | A1BG     |
# |  1 |        1 | synonym | A1B      |
# |  2 |        1 | synonym | ABG      |
# |  3 |        1 | synonym | GAB      |
# |  4 |        1 | synonym | HYST2477 |
# +----+----------+---------+----------+
# 110993
# 7800

# %%
# Look for entity types without ontology
drkg_entity_df[drkg_entity_df['ontology_name'].isna()].drop_duplicates(subset=['entity_type'])

# counts for unmatched entity types 
drkg_unmatched.groupby(by=['entity_type', 'ontology_name'], dropna=False).agg(
    count = ('code', 'count')#.sort_values(by='count')
)
# drop_duplicates(subset=['entity_type', 'ontology_name'])

# Entity types where drkg id and drkg_dict_id were different (should only be MESH terms)
# drkg_entity_df[drkg_entity_df['drkg_id'] != drkg_entity_df['drkg_dict_id']]
# Out:
#                            count
# entity_type ontology_name
# Atc         Atc             4048
# Compound    Bioarxivdrug      12
#             CHEBI              3
#             CHEMBL          1202
#             MESH            6398
#             bindingdb        144
#             brenda           731
#             chebi             25
#             drugbank           5
#             drugcentral       18
#             fdasrs             2
#             gtopdb            51
#             hmdb              12
#             molport          228
#             nmrshiftdb2        4
#             pharmgkb           1
#             pubchem           98
#             rhea              23
#             zinc              63
# Disease     MESH            1353
# Gene        drugbank        2097
#             NaN            16472
# Tax         NaN              215

# %%
# Look for entity types without ontology
drkg_entity_df[drkg_entity_df['ontology_code'].str.contains(":")==False].drop_duplicates(subset='entity_type')

# Look for unmatched entity types
drkg_unmatched.drop_duplicates(subset=['entity_type','ontology_name'])


#
# Out:
#                                      drkg_id
# 400                                   Atc::A  \
# 17220               Compound::Bioarxivdrug:0
# 17414                  Compound::CHEBI:24438
# 18296                  Compound::CHEMBL10009
# 24209                      Compound::DB02507
# 32511                 Compound::MESH:C000020
# 40133              Compound::bindingdb:11428
# 40277                 Compound::brenda:10041
# 41008                 Compound::chebi:131517
# 41033             Compound::drugcentral:1022
# 41051            Compound::fdasrs:38C836J57Z
# 41053                 Compound::gtopdb:10019
# 41104             Compound::hmdb:HMDB0010366
# 41116  Compound::molport:MolPort-001-776-387
# 41344         Compound::nmrshiftdb2:40248272
# 41348         Compound::pharmgkb:PA164743129
# 41349            Compound::pubchem:101233873
# 41447                  Compound::rhea:143079
# 41470        Compound::zinc:ZINC000000141295
# 41660                  Disease::MESH:C000590
# 46636                                 Gene::
# 83759               Gene::drugbank:BE0000001
#
#                                 drkg_dict_id name entity_type
# 400                                   Atc::A  NaN         Atc  \
# 17220               Compound::Bioarxivdrug:0  NaN    Compound
# 17414                  Compound::CHEBI:24438  NaN    Compound
# 18296                  Compound::CHEMBL10009  NaN    Compound
# 24209                      Compound::DB02507  NaN    Compound
# 32511                          MESH::C000020  NaN    Compound
# 40133              Compound::bindingdb:11428  NaN    Compound
# 40277                 Compound::brenda:10041  NaN    Compound
# 41008                 Compound::chebi:131517  NaN    Compound
# 41033             Compound::drugcentral:1022  NaN    Compound
# 41051            Compound::fdasrs:38C836J57Z  NaN    Compound
# 41053                 Compound::gtopdb:10019  NaN    Compound
# 41104             Compound::hmdb:HMDB0010366  NaN    Compound
# 41116  Compound::molport:MolPort-001-776-387  NaN    Compound
# 41344         Compound::nmrshiftdb2:40248272  NaN    Compound
# 41348         Compound::pharmgkb:PA164743129  NaN    Compound
# 41349            Compound::pubchem:101233873  NaN    Compound
# 41447                  Compound::rhea:143079  NaN    Compound
# 41470        Compound::zinc:ZINC000000141295  NaN    Compound
# 41660                          MESH::C000590  NaN     Disease
# 46636                                 Gene::  NaN        Gene
# 83759               Gene::drugbank:BE0000001  NaN        Gene
#
#                      ontology_code ontology_name                 code
# 400                              A           Atc                    A
# 17220               Bioarxivdrug:0  Bioarxivdrug                    0
# 17414                  CHEBI:24438         CHEBI                24438
# 18296                  CHEMBL10009        CHEMBL          CHEMBL10009
# 24209                      DB02507      drugbank              DB02507
# 32511                 MESH:C000020          MESH              C000020
# 40133              bindingdb:11428     bindingdb                11428
# 40277                 brenda:10041        brenda                10041
# 41008                 chebi:131517         chebi               131517
# 41033             drugcentral:1022   drugcentral                 1022
# 41051            fdasrs:38C836J57Z        fdasrs           38C836J57Z
# 41053                 gtopdb:10019        gtopdb                10019
# 41104             hmdb:HMDB0010366          hmdb          HMDB0010366
# 41116  molport:MolPort-001-776-387       molport  MolPort-001-776-387
# 41344         nmrshiftdb2:40248272   nmrshiftdb2             40248272
# 41348         pharmgkb:PA164743129      pharmgkb          PA164743129
# 41349            pubchem:101233873       pubchem            101233873
# 41447                  rhea:143079          rhea               143079
# 41470        zinc:ZINC000000141295          zinc     ZINC000000141295
# 41660                 MESH:C000590          MESH              C000590
# 46636                                       None
# 83759           drugbank:BE0000001      drugbank            BE0000001

# %% [markdown]
# #### check for relationship types where entities flip

# %%
# Create entity type dictionary and map translated words to
entitytype_dict = pd.Series(drkg_entity_df['entity_type'].values, index=drkg_entity_df['drkg_id']).to_dict() 
entityconnection_dict = pd.Series(relation_glossary['Connected entity-types'].values, index=relation_glossary['Relation-name']).to_dict() 

drkg_test    = drkg_df.copy()
drkg_test = convert_entitynames(drkg_test, 0, entitytype_dict)
drkg_test = convert_entitynames(drkg_test, 2, entitytype_dict)
drkg_test = convert_entitynames(drkg_test, 1, entityconnection_dict)
print(len(drkg_test))
print(len(drkg_test.dropna()))

drkg_test = drkg_test.dropna()
drkg_test.drop_duplicates().groupby(1).agg(
    ent_ct = (0, 'count')
)

# Only Compound:Gene and Disease:Gene have >1 pairing
# Out:
# 5874261
# 5705613
#                               ent_ct
# 1
# Anatomy:Disease                    1
# Anatomy:Gene                       1
# Biological Process:Gene            1
# Cellular Component:Gene            1
# Compound:Compound                  1
# Compound:Disease                   1
# Compound:Gene                      2
# Compound:Pharmacologic Class       1
# Compound:Side Effect               1
# Diisease:Disease                   1
# Disease:Gene                       2
# Disease:Symptom                    1
# Gene:Gene                          1
# Gene:Molecular Function            1
# Gene:Pathway                       1

# %%
# count number of head entity types (maybe the more prevalent order should be prioritized)
ent_check_list = ['Compound:Gene','Disease:Gene']
drkg_test[drkg_test[1].isin(ent_check_list)].groupby([1,0]).agg(
    ent_ct = (0, 'count')
)
# Out:
#                         ent_ct
# 1             0
# Compound:Gene Compound  126712
#               Gene       23870
# Disease:Gene  Disease    27389
#               Gene       61341

# %%
drkg_entity_df
# Out:
#                        drkg_id             drkg_dict_id
# 0      Anatomy::UBERON:0000002  Anatomy::UBERON:0000002  \
# 1      Anatomy::UBERON:0000004  Anatomy::UBERON:0000004
# 2      Anatomy::UBERON:0000006  Anatomy::UBERON:0000006
# 3      Anatomy::UBERON:0000007  Anatomy::UBERON:0000007
# 4      Anatomy::UBERON:0000010  Anatomy::UBERON:0000010
# ...                        ...                      ...
# 97018         Symptom::D063766         Symptom::D063766
# 97019         Symptom::D063806         Symptom::D063806
# 97020         Symptom::D064250         Symptom::D064250
# 97021         Symptom::D065634         Symptom::D065634
# 97022         Symptom::D065635         Symptom::D065635
#
#                                        name entity_type   ontology_code
# 0                            uterine cervix     Anatomy  UBERON:0000002  \
# 1                                      nose     Anatomy  UBERON:0000004
# 2                       islet of Langerhans     Anatomy  UBERON:0000006
# 3                           pituitary gland     Anatomy  UBERON:0000007
# 4                 peripheral nervous system     Anatomy  UBERON:0000010
# ...                                     ...         ...             ...
# 97018                     Pediatric Obesity     Symptom         D063766
# 97019                               Myalgia     Symptom         D063806
# 97020            Hypertriglyceridemic Waist     Symptom         D064250
# 97021              Cerebrospinal Fluid Leak     Symptom         D065634
# 97022  Benign Paroxysmal Positional Vertigo     Symptom         D065635
#
#       ontology_name     code
# 0            UBERON  0000002
# 1            UBERON  0000004
# 2            UBERON  0000006
# 3            UBERON  0000007
# 4            UBERON  0000010
# ...             ...      ...
# 97018          MESH  D063766
# 97019          MESH  D063806
# 97020          MESH  D064250
# 97021          MESH  D065634
# 97022          MESH  D065635
#
# [64033 rows x 7 columns]

# %%
# Look at these specific entries in DRKG
rel_check = relation_glossary[relation_glossary['Connected entity-types'].isin(ent_check_list)]

hrt_check = drkg_df[drkg_df[1].isin(rel_check['Relation-name'])].copy()
hrt_check = hrt_check.merge(rel_check.drop(columns=['Reference for the description']), how='left', left_on=1, right_on='Relation-name').drop(columns=['Relation-name'])
hrt_check = hrt_check.merge(drkg_entity_df[['drkg_id', 'entity_type']], how='inner', left_on=0, right_on='drkg_id').rename(columns={'drkg_id':'head_drkg_id', 'entity_type':'head_entity_type'})
hrt_check = hrt_check.merge(drkg_entity_df[['drkg_id', 'entity_type']], how='inner', left_on=2, right_on='drkg_id').rename(columns={'drkg_id':'tail_drkg_id', 'entity_type':'tail_entity_type'})
hrt_check = convert_entitynames(hrt_check, 0, node_dict)
hrt_check = convert_entitynames(hrt_check, 2, node_dict)

hrt_check.drop(columns=['head_drkg_id','tail_drkg_id']).drop_duplicates(subset=['Data-source', 1, 'Connected entity-types', 'head_entity_type', 'tail_entity_type']).sort_values(by=['Connected entity-types','Data-source'])
# Conclusion: switch the DGIDB gene:compound head/tails so it becomes compound -> gene; but keep the disease:gene relations the same, since they are original from hetionet (https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5640425/)
# Out:
#                                                         0
# 0       2'-deoxycytidine-2'-deoxyadenosine-3',5'-monop...  \
# 141080                   cyclin dependent kinase 7 (CDK7)
# 141081                   cyclin dependent kinase 7 (CDK7)
# 141159  gamma-aminobutyric acid type A receptor subuni...
# 141165  gamma-aminobutyric acid type A receptor subuni...
# 149736                   adenosine A2a receptor (ADORA2A)
# 149807                        ryanodine receptor 3 (RYR3)
# 149880  transient receptor potential cation channel su...
# 149929                        tumor necrosis factor (TNF)
# 150689              G protein-coupled receptor 68 (GPR68)
# 150722                serpin family A member 6 (SERPINA6)
# 170308  sodium voltage-gated channel alpha subunit 5 (...
# 180351                    opioid receptor kappa 1 (OPRK1)
# 181022  sigma non-opioid intracellular receptor 1 (SIG...
# 1       2'-deoxycytidine-2'-deoxyadenosine-3',5'-monop...
# 219                                           Doxorubicin
# 7178                               Fluticasone propionate
# 53                                               tyrosine
# 54                                               tyrosine
# 57                                             amino acid
# 61                                               Hydrogen
# 67                                              Efavirenz
# 75                                               Nicotine
# 121                                         Dexamethasone
# 286                                            Telaprevir
# 784                                             Meclizine
# 2114                                          Cobimetinib
# 22                                              Guanidine
# 2920                                            Etoposide
# 2921                                           Paclitaxel
# 1206                                            Midazolam
# 2696                                     Arachidonic Acid
# 3374               15-deoxy-Delta(12,14)-prostaglandin J2
# 3350    Severe acute respiratory syndrome-related coro...
# 5837                                       SARS-CoV2 nsp8
# 141249                   cyclin dependent kinase 7 (CDK7)
# 141270                       histamine receptor H1 (HRH1)
# 141294  dickkopf WNT signaling pathway inhibitor 1 (DKK1)
# 141301                      tachykinin precursor 1 (TAC1)
# 141362                   integrin subunit alpha L (ITGAL)
# 141421                    PML nuclear body scaffold (PML)
# 141633  CDC28 protein kinase regulatory subunit 1B (CK...
# 141731                          complement factor H (CFH)
# 141984                                     catalase (CAT)
# 142650       neuronal regeneration related protein (NREP)
# 212                                     Barrett Esophagus
# 2566                                Hematologic Neoplasms
# 2903               Pulmonary Disease, Chronic Obstructive
#
#                                                         1
# 0                        bioarx::DrugHumGen:Compound:Gene  \
# 141080                    DGIDB::INHIBITOR::Gene:Compound
# 141081                        DGIDB::OTHER::Gene:Compound
# 141159  DGIDB::POSITIVE ALLOSTERIC MODULATOR::Gene:Com...
# 141165                   DGIDB::ANTAGONIST::Gene:Compound
# 149736                      DGIDB::AGONIST::Gene:Compound
# 149807                    DGIDB::ACTIVATOR::Gene:Compound
# 149880              DGIDB::CHANNEL BLOCKER::Gene:Compound
# 149929                     DGIDB::ANTIBODY::Gene:Compound
# 150689         DGIDB::ALLOSTERIC MODULATOR::Gene:Compound
# 150722                       DGIDB::BINDER::Gene:Compound
# 170308                      DGIDB::BLOCKER::Gene:Compound
# 180351              DGIDB::PARTIAL AGONIST::Gene:Compound
# 181022                    DGIDB::MODULATOR::Gene:Compound
# 1                         DRUGBANK::target::Compound:Gene
# 219                       DRUGBANK::enzyme::Compound:Gene
# 7178                     DRUGBANK::carrier::Compound:Gene
# 53                                 GNBR::B::Compound:Gene
# 54                                 GNBR::E::Compound:Gene
# 57                                 GNBR::N::Compound:Gene
# 61                                 GNBR::K::Compound:Gene
# 67                                GNBR::E+::Compound:Gene
# 75                                GNBR::A+::Compound:Gene
# 121                                GNBR::O::Compound:Gene
# 286                               GNBR::E-::Compound:Gene
# 784                                GNBR::Z::Compound:Gene
# 2114                              GNBR::A-::Compound:Gene
# 22                           Hetionet::CbG::Compound:Gene
# 2920                         Hetionet::CdG::Compound:Gene
# 2921                         Hetionet::CuG::Compound:Gene
# 1206            INTACT::DIRECT INTERACTION::Compound:Gene
# 2696          INTACT::PHYSICAL ASSOCIATION::Compound:Gene
# 3374                   INTACT::ASSOCIATION::Compound:Gene
# 3350      bioarx::Coronavirus_ass_host_gene::Disease:Gene
# 5837           bioarx::Covid2_acc_host_gene::Disease:Gene
# 141249                              GNBR::L::Gene:Disease
# 141270                              GNBR::G::Gene:Disease
# 141294                             GNBR::Md::Gene:Disease
# 141301                              GNBR::J::Gene:Disease
# 141362                             GNBR::Te::Gene:Disease
# 141421                              GNBR::X::Gene:Disease
# 141633                              GNBR::U::Gene:Disease
# 141731                             GNBR::Ud::Gene:Disease
# 141984                              GNBR::D::Gene:Disease
# 142650                              GNBR::Y::Gene:Disease
# 212                           Hetionet::DaG::Disease:Gene
# 2566                          Hetionet::DdG::Disease:Gene
# 2903                          Hetionet::DuG::Disease:Gene
#
#                                                         2   Data-source
# 0       ribonuclease A family member 1, pancreatic (RN...  BIBLIOGRAPHY  \
# 141080                                            SNS-032         DGIDB
# 141081                                            SNS-032         DGIDB
# 141159                                      Pentobarbital         DGIDB
# 141165                                      Pentobarbital         DGIDB
# 149736                         2-Naphthalenesulfonic acid         DGIDB
# 149807                                           Caffeine         DGIDB
# 149880                                          Adenosine         DGIDB
# 149929                                     Pentoxifylline         DGIDB
# 150689                                          Lorazepam         DGIDB
# 150722                                      Triamcinolone         DGIDB
# 170308                                        Benzonatate         DGIDB
# 180351                              LEVALLORPHAN TARTRATE         DGIDB
# 181022                                PENTAZOCINE LACTATE         DGIDB
# 1       ribonuclease A family member 1, pancreatic (RN...      DRUGBANK
# 219     cytochrome P450 family 3 subfamily A member 4 ...      DRUGBANK
# 7178    solute carrier organic anion transporter famil...      DRUGBANK
# 53      ribonuclease A family member 1, pancreatic (RN...          GNBR
# 54      ribonuclease A family member 1, pancreatic (RN...          GNBR
# 57      ribonuclease A family member 1, pancreatic (RN...          GNBR
# 61      ribonuclease A family member 1, pancreatic (RN...          GNBR
# 67      nuclear receptor subfamily 1 group I member 2 ...          GNBR
# 75      nuclear receptor subfamily 1 group I member 2 ...          GNBR
# 121     nuclear receptor subfamily 1 group I member 2 ...          GNBR
# 286     cytochrome P450 family 3 subfamily A member 4 ...          GNBR
# 784     cytochrome P450 family 3 subfamily A member 4 ...          GNBR
# 2114    cytochrome P450 family 3 subfamily A member 4 ...          GNBR
# 22      ribonuclease A family member 1, pancreatic (RN...      HETIONET
# 2920    peroxisome proliferator activated receptor gam...      HETIONET
# 2921    peroxisome proliferator activated receptor gam...      HETIONET
# 1206    cytochrome P450 family 3 subfamily A member 4 ...        IntAct
# 2696        prostaglandin-endoperoxide synthase 1 (PTGS1)        IntAct
# 3374    inhibitor of nuclear factor kappa B kinase sub...        IntAct
# 3350    inhibitor of nuclear factor kappa B kinase sub...  BIBLIOGRAPHY
# 5837           mitochondrial ribosomal protein S2 (MRPS2)  BIBLIOGRAPHY
# 141249                           Carcinoma, Squamous Cell          GNBR
# 141270                           Carcinoma, Squamous Cell          GNBR
# 141294                           Carcinoma, Squamous Cell          GNBR
# 141301                           Carcinoma, Squamous Cell          GNBR
# 141362                           Carcinoma, Squamous Cell          GNBR
# 141421                           Carcinoma, Squamous Cell          GNBR
# 141633                           Carcinoma, Squamous Cell          GNBR
# 141731                           Carcinoma, Squamous Cell          GNBR
# 141984                           Carcinoma, Squamous Cell          GNBR
# 142650                                       Glioblastoma          GNBR
# 212     nuclear receptor subfamily 1 group I member 2 ...      HETIONET
# 2566                                myeloperoxidase (MPO)      HETIONET
# 2903        prostaglandin-endoperoxide synthase 1 (PTGS1)      HETIONET
#
#        Connected entity-types                         Interaction-type
# 0               Compound:Gene                              interaction  \
# 141080          Compound:Gene                               inhibition
# 141081          Compound:Gene                                    other
# 141159          Compound:Gene           positive allosteric modulation
# 141165          Compound:Gene                               antagonism
# 149736          Compound:Gene                                  agonism
# 149807          Compound:Gene                               activation
# 149880          Compound:Gene                         channel blocking
# 149929          Compound:Gene                                 antibody
# 150689          Compound:Gene                    allosteric modulation
# 150722          Compound:Gene                                  binding
# 170308          Compound:Gene                                 blocking
# 180351          Compound:Gene                          partial agonism
# 181022          Compound:Gene                               modulation
# 1               Compound:Gene                                   target
# 219             Compound:Gene                                   enzyme
# 7178            Compound:Gene                                  carrier
# 53              Compound:Gene         binding, ligand (esp. receptors)
# 54              Compound:Gene  affects expression/production (neutral)
# 57              Compound:Gene                                 inhibits
# 61              Compound:Gene             metabolism, pharmacokinetics
# 67              Compound:Gene          increases expression/production
# 75              Compound:Gene                      agonism, activation
# 121             Compound:Gene                      transport, channels
# 286             Compound:Gene          decreases expression/production
# 784             Compound:Gene                          enzyme activity
# 2114            Compound:Gene                     antagonism, blocking
# 22              Compound:Gene                                  binding
# 2920            Compound:Gene                           downregulation
# 2921            Compound:Gene                             upregulation
# 1206            Compound:Gene                        direct interation
# 2696            Compound:Gene                     physical association
# 3374            Compound:Gene                              association
# 3350             Disease:Gene                              interaction
# 5837             Disease:Gene                              interaction
# 141249           Disease:Gene    improper regulation linked to disease
# 141270           Disease:Gene                     promotes progression
# 141294           Disease:Gene                  biomarkers (diagnostic)
# 141301           Disease:Gene                     role in pathogenesis
# 141362           Disease:Gene              possible therapeutic effect
# 141421           Disease:Gene                overexpression in disease
# 141633           Disease:Gene                         causal mutations
# 141731           Disease:Gene       mutations affecting disease course
# 141984           Disease:Gene                             drug targets
# 142650           Disease:Gene                 polymorphisms alter risk
# 212              Disease:Gene                              association
# 2566             Disease:Gene                           downregulation
# 2903             Disease:Gene                             upregulation
#
#                                               Description head_entity_type
# 0                                                                 Compound  \
# 141080  In inhibitor interactions, the drug binds to a...             Gene
# 141081  This is a label given by the reporting source ...             Gene
# 141159  In a positive allosteric modulator interaction...             Gene
# 141165  An antagonist interaction occurs when a drug b...             Gene
# 149736  An agonist interaction occurs when a drug bind...             Gene
# 149807  An activator interaction is when a drug activa...             Gene
# 149880                                                                Gene
# 149929  An antibody interaction occurs when an antibod...             Gene
# 150689  An allosteric modulator interaction occurs whe...             Gene
# 150722  A binder interaction has drugs physically bind...             Gene
# 170308  Antagonist interactions are sometimes referred...             Gene
# 180351  In a partial antagonist interaction, a drug wi...             Gene
# 181022  In modulator interactions, the drug regulates ...             Gene
# 1       The drug binds or otherwise interacts with the...         Compound
# 219     Gene acts as an enzyme that facilitates the oc...         Compound
# 7178    Gene acts as a carrier which binds to a drug a...         Compound
# 53                                                                Compound
# 54                                                                Compound
# 57                                                                Compound
# 61                                                                Compound
# 67                                                                Compound
# 75                                                                Compound
# 121                                                               Compound
# 286                                                               Compound
# 784                                                               Compound
# 2114                                                              Compound
# 22                                                                Compound
# 2920                                                              Compound
# 2921                                                              Compound
# 1206    Interaction between molecules that are in dire...         Compound
# 2696    Interaction between molecules within the same ...         Compound
# 3374    Interaction between molecules that may partici...         Compound
# 3350    Interactions between the 6 Covid-19 related  d...          Disease
# 5837    Interactions between 27 viral  proteins,  and ...          Disease
# 141249                                                                Gene
# 141270                                                                Gene
# 141294                                                                Gene
# 141301                                                                Gene
# 141362                                                                Gene
# 141421                                                                Gene
# 141633                                                                Gene
# 141731                                                                Gene
# 141984                                                                Gene
# 142650                                                                Gene
# 212                                                                Disease
# 2566                                                               Disease
# 2903                                                               Disease
#
#        tail_entity_type
# 0                  Gene
# 141080         Compound
# 141081         Compound
# 141159         Compound
# 141165         Compound
# 149736         Compound
# 149807         Compound
# 149880         Compound
# 149929         Compound
# 150689         Compound
# 150722         Compound
# 170308         Compound
# 180351         Compound
# 181022         Compound
# 1                  Gene
# 219                Gene
# 7178               Gene
# 53                 Gene
# 54                 Gene
# 57                 Gene
# 61                 Gene
# 67                 Gene
# 75                 Gene
# 121                Gene
# 286                Gene
# 784                Gene
# 2114               Gene
# 22                 Gene
# 2920               Gene
# 2921               Gene
# 1206               Gene
# 2696               Gene
# 3374               Gene
# 3350               Gene
# 5837               Gene
# 141249          Disease
# 141270          Disease
# 141294          Disease
# 141301          Disease
# 141362          Disease
# 141421          Disease
# 141633          Disease
# 141731          Disease
# 141984          Disease
# 142650          Disease
# 212                Gene
# 2566               Gene
# 2903               Gene

# %%
# Flip entries

drkg_test   = drkg_df.copy()

def flip_headtail(df, search_string):
    df_update = df.copy()
    heads = df_update[0].copy()
    df_update.loc[df_update[1].str.contains(search_string), 0] = df_update[2]
    df_update.loc[df_update[1].str.contains(search_string), 2] = heads
    return df_update

drkg_test2 = flip_headtail(drkg_test, 'Gene:Compound')
drkg_test2[drkg_test[0] != drkg_test2[0]]
# Out:
#                               0                                 1            2
# 84756         Compound::DB05969   DGIDB::INHIBITOR::Gene:Compound   Gene::1022
# 84757     Compound::CHEMBL72862  DGIDB::ANTAGONIST::Gene:Compound    Gene::135
# 84758         Compound::DB00635       DGIDB::OTHER::Gene:Compound    Gene::348
# 84759         Compound::DB12007       DGIDB::OTHER::Gene:Compound   Gene::1571
# 84760         Compound::DB12874   DGIDB::INHIBITOR::Gene:Compound   Gene::5159
# ...                         ...                               ...          ...
# 111041  Compound::CHEMBL1770297  DGIDB::ANTAGONIST::Gene:Compound   Gene::2357
# 111042        Compound::DB00396       DGIDB::OTHER::Gene:Compound   Gene::1645
# 111043        Compound::DB06649     DGIDB::BLOCKER::Gene:Compound  Gene::11280
# 111044        Compound::DB11886   DGIDB::INHIBITOR::Gene:Compound   Gene::5289
# 111045        Compound::DB01208   DGIDB::INHIBITOR::Gene:Compound   Gene::7155
#
# [26290 rows x 3 columns]

# %% [markdown]
# ## Code for graph

# %%
# repeat import statements from above
# !pip install torch
# !pip install torch_geometric
# from torch_geometric.data import HeteroData
# !pip install transformers
from torch_geometric.data import HeteroData
from SIMP_LLM.llm_encode import EntityEncoder
from SIMP_LLM.dataloader_mappings import create_mapping,create_edges
# Out:
# Collecting transformers
#   Downloading transformers-4.29.2-py3-none-any.whl (7.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 9.1 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: filelock in /Users/selinapi/opt/anaconda3/envs/simp_llm/lib/python3.11/site-packages (from transformers) (3.12.0)
# Collecting huggingface-hub<1.0,>=0.14.1 (from transformers)
#   Using cached huggingface_hub-0.14.1-py3-none-any.whl (224 kB)
# Requirement already satisfied: numpy>=1.17 in /Users/selinapi/opt/anaconda3/envs/simp_llm/lib/python3.11/site-packages (from transformers) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in /Users/selinapi/opt/anaconda3/envs/simp_llm/lib/python3.11/site-packages (from transformers) (23.1)
# Collecting pyyaml>=5.1 (from transformers)
#   Using cached PyYAML-6.0-cp311-cp311-macosx_10_9_x86_64.whl (188 kB)
# Collecting regex!=2019.12.17 (from transformers)
#   Using cached regex-2023.5.5-cp311-cp311-macosx_10_9_x86_64.whl (294 kB)
# Requirement already satisfied: requests in /Users/selinapi/opt/anaconda3/envs/simp_llm/lib/python3.11/site-packages (from transformers) (2.30.0)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers)
#   Using cached tokenizers-0.13.3-cp311-cp311-macosx_10_11_universal2.whl (4.0 MB)
# Requirement already satisfied: tqdm>=4.27 in /Users/selinapi/opt/anaconda3/envs/simp_llm/lib/python3.11/site-packages (from transformers) (4.65.0)
# Collecting fsspec (from huggingface-hub<1.0,>=0.14.1->transformers)
#   Using cached fsspec-2023.5.0-py3-none-any.whl (160 kB)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/selinapi/opt/anaconda3/envs/simp_llm/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/selinapi/opt/anaconda3/envs/simp_llm/lib/python3.11/site-packages (from requests->transformers) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/selinapi/opt/anaconda3/envs/simp_llm/lib/python3.11/site-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/selinapi/opt/anaconda3/envs/simp_llm/lib/python3.11/site-packages (from requests->transformers) (2.0.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/selinapi/opt/anaconda3/envs/simp_llm/lib/python3.11/site-packages (from requests->transformers) (2023.5.7)
# Installing collected packages: tokenizers, regex, pyyaml, fsspec, huggingface-hub, transformers
# Successfully installed fsspec-2023.5.0 huggingface-hub-0.14.1 pyyaml-6.0 regex-2023.5.5 tokenizers-0.13.3 transformers-4.29.2

# %%
# TEST entity lookup
## Example of loading data without anything to encode
device    = "cpu"
Encoder  = EntityEncoder(device = device )

data_test = HeteroData()

def TEST_embed_entities(entity_df, graph_obj, Encoder, device):
    '''Embeds entities, inputs embeddings into Heterograph object, and returns mapping dictionary by entity type'''
    '''TEST: Only first 3 entities of each type'''
    entity_lookup = entity_df.copy()
    mapping_dict = {}
    for entity in entity_lookup['entity_type'].unique():
        entity_names = entity_lookup.loc[entity_lookup['entity_type'] == entity, 'name'][:3]
        entity_X, entity_mapping = create_mapping(entity_names, encoder=Encoder, device=device) # Maps entities to indices
        graph_obj[entity].x = entity_X
        mapping_dict[entity] = entity_mapping
    return mapping_dict

mapping_dict = TEST_embed_entities(drkg_entity_df, data_test, Encoder, device)
print(data_test)
print(mapping_dict['Gene'])
print(mapping_dict['Disease'])
# Out:
# HeteroData(
#   Anatomy={ x=[3, 768] },
#   Biological Process={ x=[3, 768] },
#   Cellular Component={ x=[3, 768] },
#   Compound={ x=[3, 768] },
#   Disease={ x=[3, 768] },
#   Gene={ x=[3, 768] },
#   Molecular Function={ x=[3, 768] },
#   Pathway={ x=[3, 768] },
#   Pharmacologic Class={ x=[3, 768] },
#   Side Effect={ x=[3, 768] },
#   Symptom={ x=[3, 768] }
# )
# {'adenosine deaminase (ADA)': 0, 'alpha-1-B glycoprotein (A1BG)': 1, 'N-acetyltransferase 2 (NAT2)': 2}
# {'idiopathic pulmonary fibrosis': 0, 'alcohol dependence': 1, 'restless legs syndrome': 2}

# %%
# SP 5/15/23 Functions to embed entities and append new edge types to graph

# For DRKG translation: have dictionary 

# Entity lookup table with DRKG code, English language translation, and entity type
# def embed_entities(entity_df, graph_obj, Encoder, device):
#     '''Embeds entities, inputs embeddings directly into Heterograph object, and returns mapping dictionary (which is a dictionary of dictionaries) by entity type'''
#     entity_lookup = entity_df.copy()
#     mapping_dict = {}
#     for entity in entity_lookup['entity_type'].unique():                                        # For each entity type
#         entity_names = entity_lookup.loc[entity_lookup['entity_type'] == entity, 'name']        # Get entity names associated with entity type
#         entity_X, entity_mapping = create_mapping(entity_names, encoder=Encoder, device=device) # Maps entities to indices
#         graph_obj[entity].x = entity_X                                                          # Assign entity type embeddings to graph object
#         mapping_dict[entity] = entity_mapping                                                   # Add entity type mapping to overall mapping dictionary
#     return mapping_dict


# def embed_edges(hrt_data, head_col, relation_col, tail_col, relation_lookup, graph_obj):
#     for relation_name in relation_lookup['relation_name'].unique():                                         # For each relation type
#         # Get relation codes associated with relation type and filter knowledge graph to associated relation codes
#         relation_subset = relation_lookup[relation_lookup['relation_name'] == relation_name]  
#         hrt_subset = hrt_data[hrt_data[relation_col].isin(relation_subset['drkg_id'])]   

#         # Get head and tail entity types from data, check that there is only one type for each
#         head_entity = relation_subset['head_entity']
#         tail_entity = relation_subset['tail_entity']

#         # Create edge attributes for graph
#         Edge_index,edge_attribute = create_edges(df            = hrt_subset,
#                                                 src_index_col  = head_col, 
#                                                 src_mapping    = mapping_dict[head_entity] , 
#                                                 dst_index_col  = tail_col, 
#                                                 dst_mapping    = mapping_dict[tail_entity] ,
#                                                 edge_attr      = relationship_feature)

#         graph_obj[head_entity, relation_name, tail_entity].edge_index = Edge_index
#         graph_obj[head_entity, relation_name, tail_entity].edge_label = edge_attribute 
#     return


hrt_data = df_med_translate.copy()
relation_lookup = relation_glossary.copy()

def embed_edges(hrt_data, relation_lookup, graph_obj, mapping_dict, encoder, device):
    '''
    Given dataframe with columns for head-relationship-tail (h,r,t) in that order, create edges in Heterograph object by relationship type.
    Assumes entity types are already embedded in graph.
    MAY NEED MORE WORK
    '''
    # Create mapping for relations
    relation_name_list = relation_lookup['relation_name'].unique()
    relation_X, relation_mapping = create_mapping(relation_name_list,encoder=encoder,device=device)  

    for relation_name in relation_name_list:
        # Get relation codes associated with relation type and filter knowledge graph to associated relation codes
        relation_subset = relation_lookup[relation_lookup['relation_name'] == relation_name]  
        hrt_subset = hrt_data[hrt_data[1].isin(relation_subset['drkg_id'])]   

        relation_feature = relation_X[relation_mapping[relation_name],:].reshape(1,-1)

        # Get head and tail entity types from data, check that there is only one type for each
        head_entity = relation_subset['head_entity']
        tail_entity = relation_subset['tail_entity']

        # Create edge attributes for graph
        Edge_index,edge_attribute = create_edges(df            = hrt_subset,
                                                src_index_col  = 0, 
                                                src_mapping    = mapping_dict[head_entity] , 
                                                dst_index_col  = 2, 
                                                dst_mapping    = mapping_dict[tail_entity] ,
                                                edge_attr      = relation_feature)

        graph_obj[head_entity, relation_name, tail_entity].edge_index = Edge_index
        graph_obj[head_entity, relation_name, tail_entity].edge_label = edge_attribute 
    return relation_X, relation_mapping
