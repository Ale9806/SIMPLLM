# %% [markdown]
# ### AUTHORS: All explorations by Selina Pi
#
# # Rare disease analyses

# %%
# !pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in /Users/selinapi/opt/anaconda3/envs/simp_llm/lib/python3.11/site-packages (3.1.2)
# Requirement already satisfied: et-xmlfile in /Users/selinapi/opt/anaconda3/envs/simp_llm/lib/python3.11/site-packages (from openpyxl) (1.1.0)

# %%
import numpy as np
import pandas as pd
import os 
import sys
sys.path.append('..')

# %%
from SIMP_LLM.DRKG_loading   import  read_tsv, print_head

# %%
DATA_DIR           = os.path.join("../data")
verbose            =  True

# %% [markdown]
# ## Rare diseases
#
# Prevalence of rare diseases from Orphanet 2022: https://www.orpha.net/orphacom/cahiers/docs/GB/Prevalence_of_rare_diseases_by_alphabetical_list.pdf
#
# Downloaded datasets:
#
# *  SNOMED CT-Orphanet nomenclature map from https://www.orphadata.com/alignments/ (direct link: http://www.orphadata.com/data/nomenclature/ORPHA-SNOMEDCT_Mapping_File_production.xlsx), accessed 5/22/23
#
# * Rare diseases and alignment with ICD-10, ICD-11, OMIM, UMLS, MeSH, MedDRA and GARD from https://www.orphadata.com/alignments/ (direct link: https://www.orphadata.com/data/xml/en_product1.xml, renamed en_product1-Orphadata.xml), accessed 5/22/23

# %%
relation_file = 'ORPHA-SNOMEDCT_Mapping_File_production.xlsx'
df = pd.read_excel(os.path.join(DATA_DIR,relation_file), skiprows=2)
df
# Out:
#       ORPHAcode                                    ORPHA Main term
# 0             5  Long chain 3-hydroxyacyl-CoA dehydrogenase def...  \
# 1             6        3-methylcrotonyl-CoA carboxylase deficiency
# 2             7                                        3C syndrome
# 3             8                                    47,XYY syndrome
# 4             9                                        Tetrasomy X
# ...         ...                                                ...
# 6431     589905  PHIP-related behavioral problems-intellectual ...
# 6432     590539                      Isolated melanotic schwannoma
# 6433     592570  TRAF7-associated heart defect-digital anomalie...
# 6434     595356         Localized dystrophic epidermolysis bullosa
# 6435     596448                      IgG4-related systemic disease
#
#       SNOMED concept ID
# 0             726021008
# 1              13144005
# 2             718556007
# 3              50749006
# 4              10567003
# ...                 ...
# 6431         1208987006
# 6432          404024000
# 6433         1208998007
# 6434          254186008
# 6435  10743271000119100
#
# [6436 rows x 3 columns]

# %% [markdown]
# ### Rare diseases and alignment with ICD-10 etc.

# %% [markdown]
# #### Test run with modular code

# %%
from SIMP_LLM.raredisease_loading import get_orphan_data

# %%
# Test with wrong file path
wrongpath = os.path.join(DATA_DIR, 'en_product1-Orphadat.xml')
print(os.path.isfile(wrongpath))
orphan_names, orphan_codes = get_orphan_data(wrongpath, verbose=verbose)
# Out:
# False
# Orphanet file not found in this directory. May need to download from Google Drive data folder.
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 4
#       2 wrongpath = os.path.join(DATA_DIR, 'en_product1-Orphadat.xml')
#       3 print(os.path.isfile(wrongpath))
# ----> 4 orphan_names, orphan_codes = get_orphan_data(wrongpath, verbose=verbose)
#
# File ~/SIMPLLM/Debug/../SIMP_LLM/raredisease_loading.py:158, in get_orphan_data(relation_file, verbose)
#     155 if os.path.isfile(relation_file) == False:
#     156     print('Orphanet file not found in this directory. May need to download from Google Drive data folder.')
# --> 158 tree = ET.parse(relation_file)
#     159 root = tree.getroot()[1]
#     161 ignoreElems = ['DisorderFlagList', 'DisorderType', 'DisorderGroup','DisorderDisorderAssociationList']
#
# File ~/opt/anaconda3/envs/simp_llm/lib/python3.11/xml/etree/ElementTree.py:1218, in parse(source, parser)
#    1209 """Parse XML document into element tree.
#    1210
#    1211 *source* is a filename or file object containing XML data,
#    (...)
#    1215
#    1216 """
#    1217 tree = ElementTree()
# -> 1218 tree.parse(source, parser)
#    1219 return tree
#
# File ~/opt/anaconda3/envs/simp_llm/lib/python3.11/xml/etree/ElementTree.py:569, in ElementTree.parse(self, source, parser)
#     567 close_source = False
#     568 if not hasattr(source, "read"):
# --> 569     source = open(source, "rb")
#     570     close_source = True
#     571 try:
#
# FileNotFoundError: [Errno 2] No such file or directory: '../data/en_product1-Orphadat.xml'

# %%
# Test with correct file path
orphan_names, orphan_codes = get_orphan_data(os.path.join(DATA_DIR, 'en_product1-Orphadata.xml'), verbose=verbose)
# Out:
#  Long-form orphan disease data (before processing):
#
# +----+-----------+------------------------------------------------------------------------+
# |    | cols      | data                                                                   |
# |----+-----------+------------------------------------------------------------------------|
# |  0 | Orphacode | 166024                                                                 |
# |  1 | Name      | Multiple epiphyseal dysplasia, Al-Gazali type                          |
# |  2 | Synonym   | Multiple epiphyseal dysplasia-macrocephaly-distinctive facies syndrome |
# |  3 | Source    | ICD-10                                                                 |
# |  4 | Reference | Q77.3                                                                  |
# +----+-----------+------------------------------------------------------------------------+
#
#  Long-form orphan disease data (after processing):
#
# +----+-------------------------+------------------------------------------------------------------------+--------------+---------------+--------+
# |    | cols                    | data                                                                   |   disease_id | code_source   | code   |
# |----+-------------------------+------------------------------------------------------------------------+--------------+---------------+--------|
# |  0 | Orphacode               | 166024                                                                 |       166024 |               |        |
# |  1 | Name                    | Multiple epiphyseal dysplasia, Al-Gazali type                          |       166024 |               |        |
# |  2 | Synonym                 | Multiple epiphyseal dysplasia-macrocephaly-distinctive facies syndrome |       166024 |               |        |
# |  4 | Reference               | Q77.3                                                                  |       166024 | ICD-10        | Q77.3  |
# |  6 | Disordermappingrelation | NTBT (ORPHA code's Narrower Term maps to a Broader Term)               |       166024 | ICD-10        | Q77.3  |
# +----+-------------------------+------------------------------------------------------------------------+--------------+---------------+--------+
#
#  Orphan disease name/summary data:
#
# +--------------+-------------+--------------------------------------------------------+------------------------------------------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------+
# |   disease_id |   Orphacode | Name                                                   | Synonym                                                    | Definition                                                                                                                                                                                                                                                                                                                                                                                             |   Info |
# |--------------+-------------+--------------------------------------------------------+------------------------------------------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------|
# |           10 |          10 | 48,XXYY syndrome                                       | nan                                                        | A rare sex chromosome number anomaly disorder characterized, genetically, by the presence of an extra X and Y chromosome in males and, clinically, by tall stature, dysfunctional testes associated with infertility and insufficient testosterone production, cognitive, affective and social functioning impairments, global developmental delay, and an increased risk of congenital malformations. |    nan |
# |          100 |         100 | Ataxia-telangiectasia                                  | Louis-Bar syndrome                                         | A rare disorder characterized by the association of severe combined immunodeficiency (affecting mainly the humoral immune response) with progressive cerebellar ataxia. It is characterized by neurological signs, telangiectasia, increased susceptibility to infections and a higher risk of cancer.                                                                                                 |    nan |
# |         1000 |        1000 | Ocular albinism with late-onset sensorineural deafness | Ocular albinism with late-onset sensorineural hearing loss | Ocular albinism with late-onset sensorineural deafness is a rare, X-linked inherited subtype of ocular albinism characterized by severe visual impairment, translucent pale-blue irises, a reduction in the retinal pigment and moderately severe deafness with onset ranging from adolescence to fourth or fifth decade of life.                                                                      |    nan |
# |       100000 |      100000 | Reticular perineurioma                                 | nan                                                        | nan                                                                                                                                                                                                                                                                                                                                                                                                    |    nan |
# |       100001 |      100001 | Sclerosing perineurioma                                | nan                                                        | nan                                                                                                                                                                                                                                                                                                                                                                                                    |    nan |
# +--------------+-------------+--------------------------------------------------------+------------------------------------------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------+
#
#  Orphan disease codes:
#
# +----+-------------+-----------------------------------------------+---------------+----------+----------------------------------------------------------+-----------------------------------------------------+-----------------------------------+
# |    |   Orphacode | Name                                          | code_source   | code     | Disordermappingrelation                                  | Disordermappingicdrelation                          | Disordermappingvalidationstatus   |
# |----+-------------+-----------------------------------------------+---------------+----------+----------------------------------------------------------+-----------------------------------------------------+-----------------------------------|
# |  0 |      166024 | Multiple epiphyseal dysplasia, Al-Gazali type | ICD-10        | Q77.3    | NTBT (ORPHA code's Narrower Term maps to a Broader Term) | Attributed (The ICD code is attributed by Orphanet) | Validated                         |
# |  1 |      166024 | Multiple epiphyseal dysplasia, Al-Gazali type | OMIM          | 607131   | E (Exact mapping: the two concepts are equivalent)       | nan                                                 | Validated                         |
# |  2 |      166024 | Multiple epiphyseal dysplasia, Al-Gazali type | UMLS          | C1846722 | E (Exact mapping: the two concepts are equivalent)       | nan                                                 | Validated                         |
# |  3 |          58 | Alexander disease                             | OMIM          | 203450   | E (Exact mapping: the two concepts are equivalent)       | nan                                                 | Validated                         |
# |  4 |          58 | Alexander disease                             | MeSH          | D038261  | E (Exact mapping: the two concepts are equivalent)       | nan                                                 | Validated                         |
# +----+-------------+-----------------------------------------------+---------------+----------+----------------------------------------------------------+-----------------------------------------------------+-----------------------------------+

# %%
orphan_codes
# Out:
#       Orphacode                                               Name
# 0        166024      Multiple epiphyseal dysplasia, Al-Gazali type  \
# 1        166024      Multiple epiphyseal dysplasia, Al-Gazali type
# 2        166024      Multiple epiphyseal dysplasia, Al-Gazali type
# 3            58                                  Alexander disease
# 4            58                                  Alexander disease
# ...         ...                                                ...
# 30794    620368  EGF-related primary hypomagnesemia with intell...
# 30795    617910                    Conjunctival malignant melanoma
# 30796    619948  Early-onset autoimmunity-autoinflammation-immu...
# 30797    619360  NON RARE IN EUROPE: Isolated hereditary persis...
# 30798    619233  Hereditary persistence of fetal hemoglobin-int...
#
#       code_source      code
# 0          ICD-10     Q77.3  \
# 1            OMIM    607131
# 2            UMLS  C1846722
# 3            OMIM    203450
# 4            MeSH   D038261
# ...           ...       ...
# 30794        UMLS  C5681825
# 30795        UMLS  C0346360
# 30796        UMLS  C5680416
# 30797      ICD-10     D56.4
# 30798        OMIM    617101
#
#                                  Disordermappingrelation
# 0      NTBT (ORPHA code's Narrower Term maps to a Bro...  \
# 1      E (Exact mapping: the two concepts are equival...
# 2      E (Exact mapping: the two concepts are equival...
# 3      E (Exact mapping: the two concepts are equival...
# 4      E (Exact mapping: the two concepts are equival...
# ...                                                  ...
# 30794  E (Exact mapping: the two concepts are equival...
# 30795  E (Exact mapping: the two concepts are equival...
# 30796  E (Exact mapping: the two concepts are equival...
# 30797  E (Exact mapping: the two concepts are equival...
# 30798  E (Exact mapping: the two concepts are equival...
#
#                               Disordermappingicdrelation
# 0      Attributed (The ICD code is attributed by Orph...  \
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 30794                                                NaN
# 30795                                                NaN
# 30796                                                NaN
# 30797  Specific code (The ORPHA code has its own code...
# 30798                                                NaN
#
#       Disordermappingvalidationstatus
# 0                           Validated
# 1                           Validated
# 2                           Validated
# 3                           Validated
# 4                           Validated
# ...                               ...
# 30794                       Validated
# 30795                       Validated
# 30796                       Validated
# 30797                       Validated
# 30798                       Validated
#
# [30799 rows x 7 columns]

# %% [markdown]
# #### Original messy code below

# %%
import xml.etree.ElementTree as ET

relation_file = 'en_product1-Orphadata.xml'

tree = ET.parse(os.path.join(DATA_DIR,relation_file))
root = tree.getroot()[1]

# %%
data = []
cols = []

ignoreElems = ['DisorderFlagList', 'DisorderType', 'DisorderGroup','DisorderDisorderAssociationList']
passElems = ['Disorder', 'Expertlink', 'Synonymlist', 'Externalreferencelist', 'Externalreference']
attribElems = []
appendElems = ['Synonym']
endElems = ['Externalreferencelist']

def printRecur(root):
    """Recursively adds elements to list from XML file."""
    for i, child in enumerate(root):
        if child.tag in ignoreElems:            # Fully ignore some elements and their children
            continue
        if child.tag.title() not in passElems:  # Look at child elements and add to list unless specified (doesn't work yet)
            if child.tag.title() in appendElems and i>0:
                data[-1] = data[-1] + '|' + child.attrib.get('name', child.text)
                # print(data[-1]) # Just to see how synonym string gets built
            else:
                cols.append(child.tag.title())
                if child.tag in attribElems:
                    data.append(list(child.attrib.values())[0])
                else:
                    data.append(child.attrib.get('name', child.text))
        printRecur(child)                       # Look at children of child element
    if root.tag.title() in endElems:            # Mark end of specified sections for later use
            cols.append('END_' + root.tag.title())
            data.append('\n')

printRecur(root)

long_df = pd.DataFrame([])
long_df['cols'] = cols
long_df['data'] = data
long_df
# Out:
#                                    cols
# 0                             Orphacode  \
# 1                                  Name
# 2                               Synonym
# 3                                Source
# 4                             Reference
# ...                                 ...
# 327818       Disordermappingicdrelation
# 327819  Disordermappingvalidationstatus
# 327820                             Name
# 327821        END_Externalreferencelist
# 327822           Summaryinformationlist
#
#                                                      data
# 0                                                  166024
# 1           Multiple epiphyseal dysplasia, Al-Gazali type
# 2       Multiple epiphyseal dysplasia-macrocephaly-dis...
# 3                                                  ICD-10
# 4                                                   Q77.3
# ...                                                   ...
# 327818                                               None
# 327819                                     \n
# 327820                                          Validated
# 327821                                                 \n
# 327822                                           \n
#
# [327823 rows x 2 columns]

# %%
# Clean long form orphan disease data
long_df_processed = long_df.copy()
long_df_processed = long_df_processed.dropna()
disease_id = 'Orphacode'

# Flag disease ID
long_df_processed['disease_id'] = np.where(long_df_processed['cols'] == disease_id, long_df_processed['data'], None)
long_df_processed['disease_id'] = long_df_processed['disease_id'].ffill()

# Add code source
long_df_processed['code_source'] = np.where(long_df_processed['cols'] == 'Source', long_df_processed['data'], None)
long_df_processed['code_source'] = np.where(long_df_processed['cols'] == 'END_Externalreferencelist', 'SKIP', long_df_processed['code_source'])
long_df_processed['code_source'] = long_df_processed['code_source'].ffill()

# Add code
long_df_processed['code'] = np.where(long_df_processed['cols'] == 'Reference', long_df_processed['data'], None)
long_df_processed['code'] = np.where(long_df_processed['cols'] == 'END_Externalreferencelist', 'SKIP', long_df_processed['code'])
long_df_processed['code'] = long_df_processed['code'].ffill()

# Rename 'Name' rows with true name 1 row up
long_df_processed['cols'] = np.where((long_df_processed['cols'] == 'Name') & (long_df_processed['data'].shift(1).str.startswith('\n')), long_df_processed['cols'].shift(1), long_df_processed['cols'])

# Remove \n rows
long_df_processed = long_df_processed[~long_df_processed['data'].str.startswith('\n')]

# Rename cols associated with specific source and remove source columns
# long_df_processed['cols'] = np.where(long_df_processed['code_source'].isin([None, 'SKIP']), long_df_processed['cols'], long_df_processed['code_source'] + '_' + long_df_processed['cols'])
long_df_processed = long_df_processed[~long_df_processed['cols'].str.contains('Source')]

# Manually consolidate 'definition' entries
if long_df_processed[long_df_processed['cols']=='Textsectiontype'].drop_duplicates(subset='data').shape[0] == 1:
    print('long_df_processed')
    long_df_processed['cols'] = np.where(long_df_processed['cols'] == 'Contents', 'Definition', long_df_processed['cols'])
    long_df_processed = long_df_processed[long_df_processed['cols'] != 'Textsectiontype']

long_df_processed[:20]
# # long_df_processed[long_df_processed.isnull().any(axis=1)].drop_duplicates()
# # long_df_processed[480:500]
# long_df_processed[long_df_processed['cols']=='Externalreferencelist']
# long_df_processed[20:50]
# Out:
# test
#                                cols
# 0                         Orphacode  \
# 1                              Name
# 2                           Synonym
# 4                         Reference
# 6           Disordermappingrelation
# 8        Disordermappingicdrelation
# 10  Disordermappingvalidationstatus
# 12                        Reference
# 14          Disordermappingrelation
# 17  Disordermappingvalidationstatus
# 19                        Reference
# 21          Disordermappingrelation
# 24  Disordermappingvalidationstatus
# 32                       Definition
# 33                        Orphacode
# 34                             Name
# 35                          Synonym
# 37                        Reference
# 39          Disordermappingrelation
# 42  Disordermappingvalidationstatus
#
#                                                  data disease_id code_source
# 0                                              166024     166024        None  \
# 1       Multiple epiphyseal dysplasia, Al-Gazali type     166024        None
# 2   Multiple epiphyseal dysplasia-macrocephaly-dis...     166024        None
# 4                                               Q77.3     166024      ICD-10
# 6   NTBT (ORPHA code's Narrower Term maps to a Bro...     166024      ICD-10
# 8   Attributed (The ICD code is attributed by Orph...     166024      ICD-10
# 10                                          Validated     166024      ICD-10
# 12                                             607131     166024        OMIM
# 14  E (Exact mapping: the two concepts are equival...     166024        OMIM
# 17                                          Validated     166024        OMIM
# 19                                           C1846722     166024        UMLS
# 21  E (Exact mapping: the two concepts are equival...     166024        UMLS
# 24                                          Validated     166024        UMLS
# 32  A rare primary bone dysplasia characterized by...     166024        SKIP
# 33                                                 58         58        SKIP
# 34                                  Alexander disease         58        SKIP
# 35                                                AxD         58        SKIP
# 37                                             203450         58        OMIM
# 39  E (Exact mapping: the two concepts are equival...         58        OMIM
# 42                                          Validated         58        OMIM
#
#         code
# 0       None
# 1       None
# 2       None
# 4      Q77.3
# 6      Q77.3
# 8      Q77.3
# 10     Q77.3
# 12    607131
# 14    607131
# 17    607131
# 19  C1846722
# 21  C1846722
# 24  C1846722
# 32      SKIP
# 33      SKIP
# 34      SKIP
# 35      SKIP
# 37    203450
# 39    203450
# 42    203450

# %%
# Check for duplicates
check_dupe = long_df_processed.groupby(by=['disease_id', 'code_source', 'cols']).agg(
    ct = ('data', 'count')
).reset_index()

check_dupe = check_dupe[(check_dupe['ct']>1)]

check_dupe.drop_duplicates(subset=['code_source', 'cols'])
# check_dupe[check_dupe['code_source'].isin(['SKIP', None])]
# Out:
#      disease_id code_source                             cols  ct
# 36          100        OMIM          Disordermappingrelation   2
# 37          100        OMIM  Disordermappingvalidationstatus   2
# 38          100        OMIM                        Reference   2
# 99       100006      ICD-10       Disordermappingicdrelation   2
# 100      100006      ICD-10          Disordermappingrelation   2
# 101      100006      ICD-10  Disordermappingvalidationstatus   2
# 102      100006      ICD-10                        Reference   2
# 103      100006        MeSH          Disordermappingrelation   2
# 104      100006        MeSH  Disordermappingvalidationstatus   2
# 105      100006        MeSH                        Reference   2
# 113      100006        UMLS          Disordermappingrelation   2
# 114      100006        UMLS  Disordermappingvalidationstatus   2
# 115      100006        UMLS                        Reference   2
# 2505       1020        GARD          Disordermappingrelation   2
# 2506       1020        GARD  Disordermappingvalidationstatus   2
# 2507       1020        GARD                        Reference   2
# 2620     102020      ICD-11       Disordermappingicdrelation   2
# 2621     102020      ICD-11          Disordermappingrelation   2
# 2622     102020      ICD-11  Disordermappingvalidationstatus   2
# 2623     102020      ICD-11                        Reference   2
# 5151       1199      MedDRA          Disordermappingrelation   2
# 5152       1199      MedDRA  Disordermappingvalidationstatus   2
# 5153       1199      MedDRA                        Reference   2

# %%
# Get orphan names
orphan_names = long_df_processed[long_df_processed['code_source'].isin([None, 'SKIP'])]
colnames = orphan_names['cols'].drop_duplicates().to_list()
orphan_names = pd.pivot(orphan_names,  index='disease_id', columns='cols', values='data').reindex(colnames, axis=1)
# orphan_names[orphan_names['Info'].isna()==False]
orphan_names
# Out:
# cols       Orphacode                                               Name
# disease_id
# 10                10                                   48,XXYY syndrome  \
# 100              100                              Ataxia-telangiectasia
# 1000            1000  Ocular albinism with late-onset sensorineural ...
# 100000        100000                             Reticular perineurioma
# 100001        100001                            Sclerosing perineurioma
# ...              ...                                                ...
# 99989          99989                         Intermediate DEND syndrome
# 99990          99990                              Brill-Zinsser disease
# 99991          99991                          Relapsing epidemic typhus
# 99994          99994              Complex regional pain syndrome type 2
# 99995          99995              Complex regional pain syndrome type 1
#
# cols                                                  Synonym
# disease_id
# 10                                                        NaN  \
# 100                                        Louis-Bar syndrome
# 1000        Ocular albinism with late-onset sensorineural ...
# 100000                                                    NaN
# 100001                                                    NaN
# ...                                                       ...
# 99989       Developmental delay-epilepsy-neonatal diabetes...
# 99990                       Brill disease|Recrudescent typhus
# 99991                                                     NaN
# 99994                                               Causalgia
# 99995              Algodystrophy|Reflex sympathetic dystrophy
#
# cols                                               Definition Info
# disease_id
# 10          A rare sex chromosome number anomaly disorder ...  NaN
# 100         A rare disorder characterized by the associati...  NaN
# 1000        Ocular albinism with late-onset sensorineural ...  NaN
# 100000                                                    NaN  NaN
# 100001                                                    NaN  NaN
# ...                                                       ...  ...
# 99989       A rare, genetic, neonatal diabetes mellitus sy...  NaN
# 99990                                                     NaN  NaN
# 99991                                                     NaN  NaN
# 99994       Complex regional pain syndrome type 2 (CRPS2),...  NaN
# 99995       Complex regional pain syndrome type 1 (CRPS1) ...  NaN
#
# [10705 rows x 5 columns]

# %%
# Get orphan codes
_orphan_codes = long_df_processed[~long_df_processed['code_source'].isin([None, 'SKIP'])].merge(orphan_names[['Orphacode', 'Name']], how='left', left_on='disease_id', right_on='Orphacode')
_orphan_codes['id_code'] = _orphan_codes['disease_id'] + _orphan_codes['code_source'] + _orphan_codes['code']
colnames = _orphan_codes['cols'].drop_duplicates().to_list()
orphan_codes = pd.pivot(_orphan_codes,  index='id_code', columns='cols', values='data').reindex(colnames, axis=1).reset_index()
col_list = ['Orphacode', 'Name', 'code_source', 'id_code']
orphan_codes = _orphan_codes[col_list].drop_duplicates().merge(orphan_codes, how='left', on='id_code')
orphan_codes = orphan_codes.drop(columns=['id_code']).rename(columns={'Reference':'code'})
orphan_codes
# Out:
#       Orphacode                                               Name
# 0        166024      Multiple epiphyseal dysplasia, Al-Gazali type  \
# 1        166024      Multiple epiphyseal dysplasia, Al-Gazali type
# 2        166024      Multiple epiphyseal dysplasia, Al-Gazali type
# 3            58                                  Alexander disease
# 4            58                                  Alexander disease
# ...         ...                                                ...
# 30794    620368  EGF-related primary hypomagnesemia with intell...
# 30795    617910                    Conjunctival malignant melanoma
# 30796    619948  Early-onset autoimmunity-autoinflammation-immu...
# 30797    619360  NON RARE IN EUROPE: Isolated hereditary persis...
# 30798    619233  Hereditary persistence of fetal hemoglobin-int...
#
#       code_source      code
# 0          ICD-10     Q77.3  \
# 1            OMIM    607131
# 2            UMLS  C1846722
# 3            OMIM    203450
# 4            MeSH   D038261
# ...           ...       ...
# 30794        UMLS  C5681825
# 30795        UMLS  C0346360
# 30796        UMLS  C5680416
# 30797      ICD-10     D56.4
# 30798        OMIM    617101
#
#                                  Disordermappingrelation
# 0      NTBT (ORPHA code's Narrower Term maps to a Bro...  \
# 1      E (Exact mapping: the two concepts are equival...
# 2      E (Exact mapping: the two concepts are equival...
# 3      E (Exact mapping: the two concepts are equival...
# 4      E (Exact mapping: the two concepts are equival...
# ...                                                  ...
# 30794  E (Exact mapping: the two concepts are equival...
# 30795  E (Exact mapping: the two concepts are equival...
# 30796  E (Exact mapping: the two concepts are equival...
# 30797  E (Exact mapping: the two concepts are equival...
# 30798  E (Exact mapping: the two concepts are equival...
#
#                               Disordermappingicdrelation
# 0      Attributed (The ICD code is attributed by Orph...  \
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 30794                                                NaN
# 30795                                                NaN
# 30796                                                NaN
# 30797  Specific code (The ORPHA code has its own code...
# 30798                                                NaN
#
#       Disordermappingvalidationstatus
# 0                           Validated
# 1                           Validated
# 2                           Validated
# 3                           Validated
# 4                           Validated
# ...                               ...
# 30794                       Validated
# 30795                       Validated
# 30796                       Validated
# 30797                       Validated
# 30798                       Validated
#
# [30799 rows x 7 columns]

# %%
# check for repeated?
check = 'Synonym'


# Rename 'Name' rows with true name 1 row up
long_df_processed[(long_df_processed['cols']==check) & (long_df_processed['cols'].shift(1) == check)]

long_df.iloc[357:361]
# Out:
#           cols                                               data
# 357       Name                      Multiple sulfatase deficiency
# 358    Synonym  Juvenile sulfatidosis, Austin type|MSD|Mucosul...
# 359     Source                                             ICD-10
# 360  Reference                                              E75.2

# %%
interestElems = ['Synonymlist']
appendElems = ['Synonym']

data=[]
cols=[]
def testRecur(root):
    """Recursively adds elements to list."""
    for i, child in enumerate(root):
        if child.tag.title() in appendElems:  # Look at child elements and add to list unless specified (doesn't work yet)
            # if root.tag.title() in interestElems:
            print(i)
            print(child.attrib.get('name', child.text))
            # if root.tag.title() in interestElems and i>0:
            #     data[-1] = data[-1] + '|' + child.attrib.get('name', child.text)
            #     print('test')
            # else:
            #     cols.append(child.tag.title())
            #     if child.tag in attribElems:
            #         data.append(list(child.attrib.values())[0])
            #     else:
            #         data.append(child.attrib.get('name', child.text))
        testRecur(child)                       # Look at children of child element

testRecur(root[:15])
# Out:
# 0
# Multiple epiphyseal dysplasia-macrocephaly-distinctive facies syndrome
# 0
# AxD
# 0
# Lysosomal alpha-D-mannosidase deficiency
# 0
# Aspartylglucosaminidase deficiency
# 0
# Juvenile sulfatidosis, Austin type
# 1
# MSD
# 2
# Mucosulfatidosis
# 0
# Beta-mannosidase deficiency
# 0
# Fetal-onset olivopontocerebellar hypoplasia
# 1
# PCH5
# 0
# ACY2 deficiency
# 1
# Aminoacylase 2 deficiency
# 2
# Aspartoacylase deficiency
# 3
# Spongy degeneration of the brain
# 0
# Fatal infantile encephalopathy with olivopontocerebellar hypoplasia
# 1
# Olivopontocerebellar hypoplasia
# 2
# PCH4

# %%
# check for repeated?
check = 'Orphacode'

# Rename 'Name' rows with true name 1 row up
long_df_processed[(long_df_processed['cols']==check) & (long_df_processed['cols'].shift(1) == check)]
# Out:
# Empty DataFrame
# Columns: [cols, data, code_source]
# Index: []

# %%
long_df_processed[long_df_processed['cols']=='Info']
# Out:
#         cols                                               data code_source
# 506     Info  This entity has been excluded from the Orphane...        SKIP
# 2610    Info  This term does not characterize a disease but ...        SKIP
# 2677    Info  This disease is not rare in Europe. It does no...        SKIP
# 3023    Info  This term does not characterize a disease but ...        SKIP
# 3281    Info  This disease is not rare in Europe. It does no...        SKIP
# ...      ...                                                ...         ...
# 363030  Info  This entity has been obsoleted from the Orphan...        SKIP
# 363048  Info  This entity has been obsoleted from the Orphan...        SKIP
# 363198  Info  This entity has been obsoleted from the Orphan...        SKIP
# 363216  Info  This entity has been obsoleted from the Orphan...        SKIP
# 363340  Info  This entity has been excluded from the Orphane...        SKIP
#
# [3090 rows x 3 columns]

# %%
long_df_processed.groupby('cols').agg(
    ct=('data', 'count')
)
# Out:
#                                            ct
# cols
# Definition                               6686
# Disorder                                10705
# Disorderdisorderassociationtype          2157
# GARD_Disordermappingrelation             3871
# GARD_Disordermappingvalidationstatus     3871
# GARD_Reference                           3871
# ICD-10_Disordermappingicdrelation        8500
# ICD-10_Disordermappingrelation           8500
# ICD-10_Disordermappingvalidationstatus   8500
# ICD-10_Reference                         8500
# ICD-11_Disordermappingicdrelation        1992
# ICD-11_Disordermappingrelation           1992
# ICD-11_Disordermappingvalidationstatus   1992
# ICD-11_Reference                         1992
# Info                                     3090
# MeSH_Disordermappingrelation             1798
# MeSH_Disordermappingvalidationstatus     1798
# MeSH_Reference                           1798
# MedDRA_Disordermappingrelation           1192
# MedDRA_Disordermappingvalidationstatus   1192
# MedDRA_Reference                         1192
# Name                                    12862
# OMIM_Disordermappingrelation             7947
# OMIM_Disordermappingvalidationstatus     7947
# OMIM_Reference                           7947
# Orphacode                               12862
# Synonym                                  6442
# UMLS_Disordermappingrelation             5499
# UMLS_Disordermappingvalidationstatus     5499
# UMLS_Reference                           5499

# %%
root[0][0].text
# Out:
# '166024'

# %% [markdown]
# ## Repurposed drugs

# %% [markdown]
# Data from Clue: The Drug Repurposing Hub (https://clue.io/repurposing#download-data)
#
# Latest version: 3/24/2020 <br>
# Access date: 5/22/2023

# %%
from SIMP_LLM.raredisease_loading import read_and_process_rep_drugs

# %%
# !wget https://s3.amazonaws.com/data.clue.io/repurposing/downloads/repurposing_drugs_20200324.txt
# Since this didn't work, downloaded manually to Data folder
# Out:
# zsh:1: command not found: wget

# %%
# def read_and_process_rep_drugs(relation_file, verbose=False):
#   """  
#   Process OMIM lookup table in the following ways:
#   - Remove extra variables
#   - Clean disease name
#   - Add "Disease::OMIM:" in front of OMIM ID to match DRKG format
#   """
#   df = pd.read_csv(os.path.join(DATA_DIR,relation_file), sep="\t", comment='!')

#   if verbose:
#     print(f"\n {relation_file}  Dataframe (Before processing):\n")
#     print_head(df)

#     print(f"\n {relation_file}  Dataframe (After processing):\n")
#     print_head(df)
#   return df

# %%
relation_file = 'repurposing_drugs_20200324.txt'
rep_drugs_df       =  read_and_process_rep_drugs(os.path.join(DATA_DIR, relation_file), verbose=verbose)    # Process entity names for clarity (e.g., F8 -> Gene F8) 
rep_drugs_df
# Out:
#  ../data/repurposing_drugs_20200324.txt  Dataframe (Before processing):
#
# +----+------------------------------+------------------+---------------------------------+----------------------------------------------------------------------------------------------+----------------------+---------------------+
# |    | pert_iname                   | clinical_phase   | moa                             | target                                                                                       | disease_area         | indication          |
# |----+------------------------------+------------------+---------------------------------+----------------------------------------------------------------------------------------------+----------------------+---------------------|
# |  0 | (R)-(-)-apomorphine          | Launched         | dopamine receptor agonist       | ADRA2A|ADRA2B|ADRA2C|CALY|DRD1|DRD2|DRD3|DRD4|DRD5|HTR1A|HTR1B|HTR1D|HTR2A|HTR2B|HTR2C|HTR5A | neurology/psychiatry | Parkinson's Disease |
# |  1 | (R)-(-)-rolipram             | Phase 1          | phosphodiesterase inhibitor     | PDE4A|PDE4B|PDE4C|PDE4D|PDE5A                                                                | nan                  | nan                 |
# |  2 | (R)-baclofen                 | Phase 3          | benzodiazepine receptor agonist | GABBR1|GABBR2                                                                                | nan                  | nan                 |
# |  3 | (S)-(+)-rolipram             | Phase 1          | phosphodiesterase inhibitor     | PDE4B|PDE4D                                                                                  | nan                  | nan                 |
# |  4 | [sar9,met(o2)11]-substance-p | Preclinical      | tachykinin antagonist           | TACR1                                                                                        | nan                  | nan                 |
# +----+------------------------------+------------------+---------------------------------+----------------------------------------------------------------------------------------------+----------------------+---------------------+
#
#  ../data/repurposing_drugs_20200324.txt  Dataframe (After processing):
#
# +----+------------------------------+------------------+---------------------------------+----------------------------------------------------------------------------------------------+----------------------+---------------------+
# |    | pert_iname                   | clinical_phase   | moa                             | target                                                                                       | disease_area         | indication          |
# |----+------------------------------+------------------+---------------------------------+----------------------------------------------------------------------------------------------+----------------------+---------------------|
# |  0 | (R)-(-)-apomorphine          | Launched         | dopamine receptor agonist       | ADRA2A|ADRA2B|ADRA2C|CALY|DRD1|DRD2|DRD3|DRD4|DRD5|HTR1A|HTR1B|HTR1D|HTR2A|HTR2B|HTR2C|HTR5A | neurology/psychiatry | Parkinson's Disease |
# |  1 | (R)-(-)-rolipram             | Phase 1          | phosphodiesterase inhibitor     | PDE4A|PDE4B|PDE4C|PDE4D|PDE5A                                                                | nan                  | nan                 |
# |  2 | (R)-baclofen                 | Phase 3          | benzodiazepine receptor agonist | GABBR1|GABBR2                                                                                | nan                  | nan                 |
# |  3 | (S)-(+)-rolipram             | Phase 1          | phosphodiesterase inhibitor     | PDE4B|PDE4D                                                                                  | nan                  | nan                 |
# |  4 | [sar9,met(o2)11]-substance-p | Preclinical      | tachykinin antagonist           | TACR1                                                                                        | nan                  | nan                 |
# +----+------------------------------+------------------+---------------------------------+----------------------------------------------------------------------------------------------+----------------------+---------------------+
#                         pert_iname clinical_phase
# 0              (R)-(-)-apomorphine       Launched  \
# 1                 (R)-(-)-rolipram        Phase 1
# 2                     (R)-baclofen        Phase 3
# 3                 (S)-(+)-rolipram        Phase 1
# 4     [sar9,met(o2)11]-substance-p    Preclinical
# ...                            ...            ...
# 6793                      8-M-PDOT    Preclinical
# 6794                    80841-78-7    Preclinical
# 6795               9-aminoacridine    Preclinical
# 6796           9-aminocamptothecin        Phase 2
# 6797   9-anthracenecarboxylic-acid    Preclinical
#
#                                   moa
# 0           dopamine receptor agonist  \
# 1         phosphodiesterase inhibitor
# 2     benzodiazepine receptor agonist
# 3         phosphodiesterase inhibitor
# 4               tachykinin antagonist
# ...                               ...
# 6793       melatonin receptor agonist
# 6794                              NaN
# 6795                              NaN
# 6796          topoisomerase inhibitor
# 6797                              NaN
#
#                                                  target          disease_area
# 0     ADRA2A|ADRA2B|ADRA2C|CALY|DRD1|DRD2|DRD3|DRD4|...  neurology/psychiatry  \
# 1                         PDE4A|PDE4B|PDE4C|PDE4D|PDE5A                   NaN
# 2                                         GABBR1|GABBR2                   NaN
# 3                                           PDE4B|PDE4D                   NaN
# 4                                                 TACR1                   NaN
# ...                                                 ...                   ...
# 6793                                      MTNR1A|MTNR1B                   NaN
# 6794                                                NaN                   NaN
# 6795                                                NaN                   NaN
# 6796                                               TOP1                   NaN
# 6797                                         ANO1|CLCN1                   NaN
#
#                indication
# 0     Parkinson's Disease
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# ...                   ...
# 6793                  NaN
# 6794                  NaN
# 6795                  NaN
# 6796                  NaN
# 6797                  NaN
#
# [6798 rows x 6 columns]

# %%
rep_drugs_df[~rep_drugs_df['indication'].isna()]
# Out:
#                           pert_iname clinical_phase
# 0                (R)-(-)-apomorphine       Launched  \
# 32                          abacavir       Launched
# 34                         abamectin       Launched
# 39                       abemaciclib       Launched
# 40                       abiraterone       Launched
# ...                              ...            ...
# 6697  3-(4-methylbenzylidene)camphor       Launched
# 6725            4-aminohippuric-acid       Launched
# 6755           5-aminolevulinic-acid       Launched
# 6760                  5-fluorouracil       Launched
# 6766             5-hydroxytryptophan       Launched
#
#                                              moa
# 0                      dopamine receptor agonist  \
# 32    nucleoside reverse transcriptase inhibitor
# 34               benzodiazepine receptor agonist
# 39                                 CDK inhibitor
# 40               androgen biosynthesis inhibitor
# ...                                          ...
# 6697                         endocrine disruptor
# 6725                                         NaN
# 6755                             oxidizing agent
# 6760              thymidylate synthase inhibitor
# 6766                            neurotransmitter
#
#                                                  target          disease_area
# 0     ADRA2A|ADRA2B|ADRA2C|CALY|DRD1|DRD2|DRD3|DRD4|...  neurology/psychiatry  \
# 32                                                  NaN    infectious disease
# 34                                        GABBR1|GABBR2    infectious disease
# 39                                            CDK4|CDK6              oncology
# 40                                      CYP11B1|CYP17A1              oncology
# ...                                                 ...                   ...
# 6697                                                NaN           dermatology
# 6725                                            SLC22A6            nephrology
# 6755                                               ALAD  oncology|dermatology
# 6760                                          DPYD|TYMS              oncology
# 6766                                    SLC36A1|SLC36A2  neurology/psychiatry
#
#                                              indication
# 0                                   Parkinson's Disease
# 32                 human immunodeficiency virus (HIV-1)
# 34                           gastrointestinal parasites
# 39                                        breast cancer
# 40                                      prostate cancer
# ...                                                 ...
# 6697                                   sunscreen lotion
# 6725                             renal diagnostic agent
# 6755                      glioma|actinic keratosis (AK)
# 6760  colorectal cancer|breast cancer|pancreatic can...
# 6766                                           insomnia
#
# [2222 rows x 6 columns]
