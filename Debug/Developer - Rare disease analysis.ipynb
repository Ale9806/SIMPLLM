# %% [markdown]
# # Rare disease analyses

# %%
# !pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in /Users/selinapi/opt/anaconda3/envs/simp_llm/lib/python3.11/site-packages (3.1.2)
# Requirement already satisfied: et-xmlfile in /Users/selinapi/opt/anaconda3/envs/simp_llm/lib/python3.11/site-packages (from openpyxl) (1.1.0)

# %%
import numpy as np
import pandas as pd
import os 
import sys
sys.path.append('..')

# %%
from SIMP_LLM.DRKG_loading   import  read_tsv, print_head

# %%
DATA_DIR           = os.path.join("../data")
verbose            =  True

# %% [markdown]
# ## Rare diseases
#
# Prevalence of rare diseases from Orphanet 2022: https://www.orpha.net/orphacom/cahiers/docs/GB/Prevalence_of_rare_diseases_by_alphabetical_list.pdf
#
# Downloaded datasets:
#
# *  SNOMED CT-Orphanet nomenclature map from https://www.orphadata.com/alignments/ (direct link: http://www.orphadata.com/data/nomenclature/ORPHA-SNOMEDCT_Mapping_File_production.xlsx), accessed 5/22/23
#
# * Rare diseases and alignment with ICD-10, ICD-11, OMIM, UMLS, MeSH, MedDRA and GARD from https://www.orphadata.com/alignments/ (direct link: https://www.orphadata.com/data/xml/en_product1.xml, renamed en_product1-Orphadata.xml), accessed 5/22/23

# %%
relation_file = 'ORPHA-SNOMEDCT_Mapping_File_production.xlsx'
df = pd.read_excel(os.path.join(DATA_DIR,relation_file), skiprows=2)
df
# Out:
#       ORPHAcode                                    ORPHA Main term
# 0             5  Long chain 3-hydroxyacyl-CoA dehydrogenase def...  \
# 1             6        3-methylcrotonyl-CoA carboxylase deficiency
# 2             7                                        3C syndrome
# 3             8                                    47,XYY syndrome
# 4             9                                        Tetrasomy X
# ...         ...                                                ...
# 6431     589905  PHIP-related behavioral problems-intellectual ...
# 6432     590539                      Isolated melanotic schwannoma
# 6433     592570  TRAF7-associated heart defect-digital anomalie...
# 6434     595356         Localized dystrophic epidermolysis bullosa
# 6435     596448                      IgG4-related systemic disease
#
#       SNOMED concept ID
# 0             726021008
# 1              13144005
# 2             718556007
# 3              50749006
# 4              10567003
# ...                 ...
# 6431         1208987006
# 6432          404024000
# 6433         1208998007
# 6434          254186008
# 6435  10743271000119100
#
# [6436 rows x 3 columns]

# %%
import xml.etree.ElementTree as ET

relation_file = 'en_product1-Orphadata.xml'

tree = ET.parse(os.path.join(DATA_DIR,relation_file))
root = tree.getroot()[1]

# %%
data = []
cols = []

ignoreElems = ['DisorderFlagList', 'DisorderType', 'DisorderGroup','DisorderDisorderAssociationList']
passElems = ['Disorder', 'Expertlink', 'Synonymlist', 'Externalreferencelist', 'Externalreference']
attribElems = []
appendElems = ['Synonym']
endElems = ['Externalreferencelist']

def printRecur(root):
    """Recursively adds elements to list."""
    for i, child in enumerate(root):
        if child.tag in ignoreElems:            # Fully ignore some elements and their children
            continue
        if child.tag.title() not in passElems:  # Look at child elements and add to list unless specified (doesn't work yet)
            if child.tag.title() in appendElems and i>0:
                data[-1] = data[-1] + '|' + child.attrib.get('name', child.text)
                # print(data[-1]) # Just to see how synonym string gets built
            else:
                cols.append(child.tag.title())
                if child.tag in attribElems:
                    data.append(list(child.attrib.values())[0])
                else:
                    data.append(child.attrib.get('name', child.text))
        printRecur(child)                       # Look at children of child element
    if root.tag.title() in endElems:            # Mark end of specified sections for later use
            cols.append('END_' + root.tag.title())
            data.append('\n')

printRecur(root)

long_df = pd.DataFrame([])
long_df['cols'] = cols
long_df['data'] = data
long_df
# Out:
#                                    cols
# 0                             Orphacode  \
# 1                                  Name
# 2                               Synonym
# 3                                Source
# 4                             Reference
# ...                                 ...
# 327818       Disordermappingicdrelation
# 327819  Disordermappingvalidationstatus
# 327820                             Name
# 327821        END_Externalreferencelist
# 327822           Summaryinformationlist
#
#                                                      data
# 0                                                  166024
# 1           Multiple epiphyseal dysplasia, Al-Gazali type
# 2       Multiple epiphyseal dysplasia-macrocephaly-dis...
# 3                                                  ICD-10
# 4                                                   Q77.3
# ...                                                   ...
# 327818                                               None
# 327819                                     \n
# 327820                                          Validated
# 327821                                                 \n
# 327822                                           \n
#
# [327823 rows x 2 columns]

# %%
# Clean long form orphan disease data
test = long_df.copy()
test = test.dropna()
disease_id = 'Orphacode'

# Flag disease ID
test['disease_id'] = np.where(test['cols'] == disease_id, test['data'], None)
test['disease_id'] = test['disease_id'].ffill()

# Flag code source
test['code_source'] = np.where(test['cols'] == 'Source', test['data'], None)
test['code_source'] = np.where(test['cols'] == 'END_Externalreferencelist', 'SKIP', test['code_source'])
test['code_source'] = test['code_source'].ffill()

# Rename 'Name' rows with true name 1 row up
test['cols'] = np.where((test['cols'] == 'Name') & (test['data'].shift(1).str.startswith('\n')), test['cols'].shift(1), test['cols'])

# Remove \n rows
test = test[~test['data'].str.startswith('\n')]

# Rename cols associated with specific source and remove source columns
# test['cols'] = np.where(test['code_source'].isin([None, 'SKIP']), test['cols'], test['code_source'] + '_' + test['cols'])
test = test[~test['cols'].str.contains('Source')]

# Manually consolidate 'definition' entries
if test[test['cols']=='Textsectiontype'].drop_duplicates().shape[0] == 1:
    test['cols'] = np.where(test['cols'] == 'Contents', 'Definition', test['cols'])
    test = test[test['cols'] != 'Textsectiontype']

test[:20]
# # test[test.isnull().any(axis=1)].drop_duplicates()
# # test[480:500]
# test[test['cols']=='Externalreferencelist']
# test[20:50]
# Out:
#                                cols
# 0                         Orphacode  \
# 1                              Name
# 2                           Synonym
# 4                         Reference
# 6           Disordermappingrelation
# 8        Disordermappingicdrelation
# 10  Disordermappingvalidationstatus
# 12                        Reference
# 14          Disordermappingrelation
# 17  Disordermappingvalidationstatus
# 19                        Reference
# 21          Disordermappingrelation
# 24  Disordermappingvalidationstatus
# 31                  Textsectiontype
# 32                         Contents
# 33                        Orphacode
# 34                             Name
# 35                          Synonym
# 37                        Reference
# 39          Disordermappingrelation
#
#                                                  data disease_id code_source
# 0                                              166024     166024        None
# 1       Multiple epiphyseal dysplasia, Al-Gazali type     166024        None
# 2   Multiple epiphyseal dysplasia-macrocephaly-dis...     166024        None
# 4                                               Q77.3     166024      ICD-10
# 6   NTBT (ORPHA code's Narrower Term maps to a Bro...     166024      ICD-10
# 8   Attributed (The ICD code is attributed by Orph...     166024      ICD-10
# 10                                          Validated     166024      ICD-10
# 12                                             607131     166024        OMIM
# 14  E (Exact mapping: the two concepts are equival...     166024        OMIM
# 17                                          Validated     166024        OMIM
# 19                                           C1846722     166024        UMLS
# 21  E (Exact mapping: the two concepts are equival...     166024        UMLS
# 24                                          Validated     166024        UMLS
# 31                                         Definition     166024        SKIP
# 32  A rare primary bone dysplasia characterized by...     166024        SKIP
# 33                                                 58         58        SKIP
# 34                                  Alexander disease         58        SKIP
# 35                                                AxD         58        SKIP
# 37                                             203450         58        OMIM
# 39  E (Exact mapping: the two concepts are equival...         58        OMIM

# %%
# Check for duplicates
check_dupe = test.groupby(by=['disease_id', 'code_source', 'cols']).agg(
    ct = ('data', 'count')
).reset_index()

check_dupe = check_dupe[(check_dupe['ct']>1)]

# check_dupe['cols'].drop_duplicates()
check_dupe[check_dupe['code_source'].isin(['SKIP', None])]
# Out:
# Empty DataFrame
# Columns: [disease_id, code_source, cols, ct]
# Index: []

# %%
test[test['disease_id']=='10']
# Out:
#                                        cols
# 647                                Disorder  \
# 648                               Orphacode
# 649                                    Name
# 651                        ICD-10_Reference
# 653          ICD-10_Disordermappingrelation
# 655       ICD-10_Disordermappingicdrelation
# 657  ICD-10_Disordermappingvalidationstatus
# 659                        ICD-10_Reference
# 661          ICD-10_Disordermappingrelation
# 663       ICD-10_Disordermappingicdrelation
# 665  ICD-10_Disordermappingvalidationstatus
# 667                        ICD-10_Reference
# 669          ICD-10_Disordermappingrelation
# 671       ICD-10_Disordermappingicdrelation
# 673  ICD-10_Disordermappingvalidationstatus
#
#                                                   data disease_id code_source
# 647                                                 10         10        SKIP
# 648                                                206         10        SKIP
# 649                  NON RARE IN EUROPE: Crohn disease         10        SKIP
# 651                                              K50.1         10      ICD-10
# 653  BTNT (ORPHA code's Broader Term maps to a Narr...         10      ICD-10
# 655  Specific code (The ORPHA code has its own code...         10      ICD-10
# 657                                          Validated         10      ICD-10
# 659                                              K50.0         10      ICD-10
# 661  BTNT (ORPHA code's Broader Term maps to a Narr...         10      ICD-10
# 663  Specific code (The ORPHA code has its own code...         10      ICD-10
# 665                                          Validated         10      ICD-10
# 667                                              K50.8         10      ICD-10
# 669  BTNT (ORPHA code's Broader Term maps to a Narr...         10      ICD-10
# 671  Specific code (The ORPHA code has its own code...         10      ICD-10
# 673                                          Validated         10      ICD-10

# %%
test2 = pd.pivot(test,  index='disease_id', columns='cols', values='data')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 test2 = pd.pivot(test,  index='disease_id', columns='cols', values='data')
#
# File ~/opt/anaconda3/envs/simp_llm/lib/python3.11/site-packages/pandas/core/reshape/pivot.py:557, in pivot(data, columns, index, values)
#     553         indexed = data._constructor_sliced(data[values]._values, index=multiindex)
#     554 # error: Argument 1 to "unstack" of "DataFrame" has incompatible type "Union
#     555 # [List[Any], ExtensionArray, ndarray[Any, Any], Index, Series]"; expected
#     556 # "Hashable"
# --> 557 result = indexed.unstack(columns_listlike)  # type: ignore[arg-type]
#     558 result.index.names = [
#     559     name if name is not lib.NoDefault else None for name in result.index.names
#     560 ]
#     562 return result
#
# File ~/opt/anaconda3/envs/simp_llm/lib/python3.11/site-packages/pandas/core/series.py:4309, in Series.unstack(self, level, fill_value)
#    4266 """
#    4267 Unstack, also known as pivot, Series with MultiIndex to produce DataFrame.
#    4268
#    (...)
#    4305 b    2    4
#    4306 """
#    4307 from pandas.core.reshape.reshape import unstack
# -> 4309 return unstack(self, level, fill_value)
#
# File ~/opt/anaconda3/envs/simp_llm/lib/python3.11/site-packages/pandas/core/reshape/reshape.py:488, in unstack(obj, level, fill_value)
#     486 if is_1d_only_ea_dtype(obj.dtype):
#     487     return _unstack_extension_series(obj, level, fill_value)
# --> 488 unstacker = _Unstacker(
#     489     obj.index, level=level, constructor=obj._constructor_expanddim
#     490 )
#     491 return unstacker.get_result(
#     492     obj._values, value_columns=None, fill_value=fill_value
#     493 )
#
# File ~/opt/anaconda3/envs/simp_llm/lib/python3.11/site-packages/pandas/core/reshape/reshape.py:136, in _Unstacker.__init__(self, index, level, constructor)
#     128 if num_cells > np.iinfo(np.int32).max:
#     129     warnings.warn(
#     130         f"The following operation may generate {num_cells} cells "
#     131         f"in the resulting pandas object.",
#     132         PerformanceWarning,
#     133         stacklevel=find_stack_level(),
#     134     )
# --> 136 self._make_selectors()
#
# File ~/opt/anaconda3/envs/simp_llm/lib/python3.11/site-packages/pandas/core/reshape/reshape.py:188, in _Unstacker._make_selectors(self)
#     185 mask.put(selector, True)
#     187 if mask.sum() < len(self.index):
# --> 188     raise ValueError("Index contains duplicate entries, cannot reshape")
#     190 self.group_index = comp_index
#     191 self.mask = mask
#
# ValueError: Index contains duplicate entries, cannot reshape

# %%
test2
# Out:
# cols   Definition Disorder Disorderdisorderassociationtype
# 0             NaN    17601                             NaN  \
# 1             NaN      NaN                             NaN
# 2             NaN      NaN                             NaN
# 3             NaN      NaN                             NaN
# 5             NaN      NaN                             NaN
# ...           ...      ...                             ...
# 364320        NaN      NaN                             NaN
# 364321        NaN      NaN                             NaN
# 364323        NaN      NaN                             NaN
# 364325        NaN      NaN                             NaN
# 364328        NaN      NaN                             NaN
#
# cols   GARD_Disordermappingrelation GARD_Disordermappingvalidationstatus
# 0                               NaN                                  NaN  \
# 1                               NaN                                  NaN
# 2                               NaN                                  NaN
# 3                               NaN                                  NaN
# 5                               NaN                                  NaN
# ...                             ...                                  ...
# 364320                          NaN                                  NaN
# 364321                          NaN                                  NaN
# 364323                          NaN                                  NaN
# 364325                          NaN                                  NaN
# 364328                          NaN                                  NaN
#
# cols   GARD_Reference ICD-10_Disordermappingicdrelation
# 0                 NaN                               NaN  \
# 1                 NaN                               NaN
# 2                 NaN                               NaN
# 3                 NaN                               NaN
# 5                 NaN                               NaN
# ...               ...                               ...
# 364320            NaN                               NaN
# 364321            NaN                               NaN
# 364323            NaN                               NaN
# 364325            NaN                               NaN
# 364328            NaN                               NaN
#
# cols   ICD-10_Disordermappingrelation ICD-10_Disordermappingvalidationstatus
# 0                                 NaN                                    NaN  \
# 1                                 NaN                                    NaN
# 2                                 NaN                                    NaN
# 3                                 NaN                                    NaN
# 5                                 NaN                                    NaN
# ...                               ...                                    ...
# 364320                            NaN                                    NaN
# 364321                            NaN                                    NaN
# 364323                            NaN                                    NaN
# 364325                            NaN                                    NaN
# 364328                            NaN                                    NaN
#
# cols   ICD-10_Reference  ... MedDRA_Reference
# 0                   NaN  ...              NaN  \
# 1                   NaN  ...              NaN
# 2                   NaN  ...              NaN
# 3                   NaN  ...              NaN
# 5                 Q77.3  ...              NaN
# ...                 ...  ...              ...
# 364320              NaN  ...              NaN
# 364321              NaN  ...              NaN
# 364323              NaN  ...              NaN
# 364325              NaN  ...              NaN
# 364328              NaN  ...              NaN
#
# cols                                                 Name
# 0                                                     NaN  \
# 1                                                     NaN
# 2           Multiple epiphyseal dysplasia, Al-Gazali type
# 3                                                     NaN
# 5                                                     NaN
# ...                                                   ...
# 364320  Hereditary persistence of fetal hemoglobin-int...
# 364321                                                NaN
# 364323                                                NaN
# 364325                                                NaN
# 364328                                                NaN
#
# cols                         OMIM_Disordermappingrelation
# 0                                                     NaN  \
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 5                                                     NaN
# ...                                                   ...
# 364320                                                NaN
# 364321                                                NaN
# 364323                                                NaN
# 364325  E (Exact mapping: the two concepts are equival...
# 364328                                                NaN
#
# cols   OMIM_Disordermappingvalidationstatus OMIM_Reference Orphacode
# 0                                       NaN            NaN       NaN  \
# 1                                       NaN            NaN    166024
# 2                                       NaN            NaN       NaN
# 3                                       NaN            NaN       NaN
# 5                                       NaN            NaN       NaN
# ...                                     ...            ...       ...
# 364320                                  NaN            NaN       NaN
# 364321                                  NaN            NaN       NaN
# 364323                                  NaN         617101       NaN
# 364325                                  NaN            NaN       NaN
# 364328                            Validated            NaN       NaN
#
# cols                                              Synonym
# 0                                                     NaN  \
# 1                                                     NaN
# 2                                                     NaN
# 3       Multiple epiphyseal dysplasia-macrocephaly-dis...
# 5                                                     NaN
# ...                                                   ...
# 364320                                                NaN
# 364321                                Dias-Logan syndrome
# 364323                                                NaN
# 364325                                                NaN
# 364328                                                NaN
#
# cols   UMLS_Disordermappingrelation UMLS_Disordermappingvalidationstatus
# 0                               NaN                                  NaN  \
# 1                               NaN                                  NaN
# 2                               NaN                                  NaN
# 3                               NaN                                  NaN
# 5                               NaN                                  NaN
# ...                             ...                                  ...
# 364320                          NaN                                  NaN
# 364321                          NaN                                  NaN
# 364323                          NaN                                  NaN
# 364325                          NaN                                  NaN
# 364328                          NaN                                  NaN
#
# cols   UMLS_Reference
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 5                 NaN
# ...               ...
# 364320            NaN
# 364321            NaN
# 364323            NaN
# 364325            NaN
# 364328            NaN
#
# [157693 rows x 30 columns]

# %%
# check for repeated?
check = 'Synonym'


# Rename 'Name' rows with true name 1 row up
test[(test['cols']==check) & (test['cols'].shift(1) == check)]

long_df.iloc[357:361]
# Out:
#           cols                                               data
# 357       Name                      Multiple sulfatase deficiency
# 358    Synonym  Juvenile sulfatidosis, Austin type|MSD|Mucosul...
# 359     Source                                             ICD-10
# 360  Reference                                              E75.2

# %%
interestElems = ['Synonymlist']
appendElems = ['Synonym']

data=[]
cols=[]
def testRecur(root):
    """Recursively adds elements to list."""
    for i, child in enumerate(root):
        if child.tag.title() in appendElems:  # Look at child elements and add to list unless specified (doesn't work yet)
            # if root.tag.title() in interestElems:
            print(i)
            print(child.attrib.get('name', child.text))
            # if root.tag.title() in interestElems and i>0:
            #     data[-1] = data[-1] + '|' + child.attrib.get('name', child.text)
            #     print('test')
            # else:
            #     cols.append(child.tag.title())
            #     if child.tag in attribElems:
            #         data.append(list(child.attrib.values())[0])
            #     else:
            #         data.append(child.attrib.get('name', child.text))
        testRecur(child)                       # Look at children of child element

testRecur(root[:15])
# Out:
# 0
# Multiple epiphyseal dysplasia-macrocephaly-distinctive facies syndrome
# 0
# AxD
# 0
# Lysosomal alpha-D-mannosidase deficiency
# 0
# Aspartylglucosaminidase deficiency
# 0
# Juvenile sulfatidosis, Austin type
# 1
# MSD
# 2
# Mucosulfatidosis
# 0
# Beta-mannosidase deficiency
# 0
# Fetal-onset olivopontocerebellar hypoplasia
# 1
# PCH5
# 0
# ACY2 deficiency
# 1
# Aminoacylase 2 deficiency
# 2
# Aspartoacylase deficiency
# 3
# Spongy degeneration of the brain
# 0
# Fatal infantile encephalopathy with olivopontocerebellar hypoplasia
# 1
# Olivopontocerebellar hypoplasia
# 2
# PCH4

# %%
# check for repeated?
check = 'Orphacode'

# Rename 'Name' rows with true name 1 row up
test[(test['cols']==check) & (test['cols'].shift(1) == check)]
# Out:
# Empty DataFrame
# Columns: [cols, data, code_source]
# Index: []

# %%
test[test['cols']=='Info']
# Out:
#         cols                                               data code_source
# 506     Info  This entity has been excluded from the Orphane...        SKIP
# 2610    Info  This term does not characterize a disease but ...        SKIP
# 2677    Info  This disease is not rare in Europe. It does no...        SKIP
# 3023    Info  This term does not characterize a disease but ...        SKIP
# 3281    Info  This disease is not rare in Europe. It does no...        SKIP
# ...      ...                                                ...         ...
# 363030  Info  This entity has been obsoleted from the Orphan...        SKIP
# 363048  Info  This entity has been obsoleted from the Orphan...        SKIP
# 363198  Info  This entity has been obsoleted from the Orphan...        SKIP
# 363216  Info  This entity has been obsoleted from the Orphan...        SKIP
# 363340  Info  This entity has been excluded from the Orphane...        SKIP
#
# [3090 rows x 3 columns]

# %%
test.groupby('cols').agg(
    ct=('data', 'count')
)
# Out:
#                                            ct
# cols
# Definition                               6686
# Disorder                                10705
# Disorderdisorderassociationtype          2157
# GARD_Disordermappingrelation             3871
# GARD_Disordermappingvalidationstatus     3871
# GARD_Reference                           3871
# ICD-10_Disordermappingicdrelation        8500
# ICD-10_Disordermappingrelation           8500
# ICD-10_Disordermappingvalidationstatus   8500
# ICD-10_Reference                         8500
# ICD-11_Disordermappingicdrelation        1992
# ICD-11_Disordermappingrelation           1992
# ICD-11_Disordermappingvalidationstatus   1992
# ICD-11_Reference                         1992
# Info                                     3090
# MeSH_Disordermappingrelation             1798
# MeSH_Disordermappingvalidationstatus     1798
# MeSH_Reference                           1798
# MedDRA_Disordermappingrelation           1192
# MedDRA_Disordermappingvalidationstatus   1192
# MedDRA_Reference                         1192
# Name                                    12862
# OMIM_Disordermappingrelation             7947
# OMIM_Disordermappingvalidationstatus     7947
# OMIM_Reference                           7947
# Orphacode                               12862
# Synonym                                  6442
# UMLS_Disordermappingrelation             5499
# UMLS_Disordermappingvalidationstatus     5499
# UMLS_Reference                           5499

# %%
root[0][0].text
# Out:
# '166024'

# %% [markdown]
# ## Repurposed drugs

# %% [markdown]
# Data from Clue: The Drug Repurposing Hub (https://clue.io/repurposing#download-data)
#
# Latest version: 3/24/2020 <br>
# Access date: 5/22/2023

# %%
# !wget https://s3.amazonaws.com/data.clue.io/repurposing/downloads/repurposing_drugs_20200324.txt
# Since this didn't work, downloaded manually to Data folder
# Out:
# zsh:1: command not found: wget

# %%
def read_and_process_rep_drugs(relation_file, verbose=False):
  """  
  Process OMIM lookup table in the following ways:
  - Remove extra variables
  - Clean disease name
  - Add "Disease::OMIM:" in front of OMIM ID to match DRKG format
  """
  df = pd.read_csv(os.path.join(DATA_DIR,relation_file), sep="\t", comment='!')

  if verbose:
    print(f"\n {relation_file}  Dataframe (Before processing):\n")
    print_head(df)

    print(f"\n {relation_file}  Dataframe (After processing):\n")
    print_head(df)
  return df

# %%
relation_file = 'repurposing_drugs_20200324.txt'
rep_drugs_df       =  read_and_process_rep_drugs(relation_file, verbose=verbose)    # Process entity names for clarity (e.g., F8 -> Gene F8) 
rep_drugs_df
# Out:
#  repurposing_drugs_20200324.txt  Dataframe (Before processing):
#
# +----+------------------------------+------------------+---------------------------------+----------------------------------------------------------------------------------------------+----------------------+---------------------+
# |    | pert_iname                   | clinical_phase   | moa                             | target                                                                                       | disease_area         | indication          |
# |----+------------------------------+------------------+---------------------------------+----------------------------------------------------------------------------------------------+----------------------+---------------------|
# |  0 | (R)-(-)-apomorphine          | Launched         | dopamine receptor agonist       | ADRA2A|ADRA2B|ADRA2C|CALY|DRD1|DRD2|DRD3|DRD4|DRD5|HTR1A|HTR1B|HTR1D|HTR2A|HTR2B|HTR2C|HTR5A | neurology/psychiatry | Parkinson's Disease |
# |  1 | (R)-(-)-rolipram             | Phase 1          | phosphodiesterase inhibitor     | PDE4A|PDE4B|PDE4C|PDE4D|PDE5A                                                                | nan                  | nan                 |
# |  2 | (R)-baclofen                 | Phase 3          | benzodiazepine receptor agonist | GABBR1|GABBR2                                                                                | nan                  | nan                 |
# |  3 | (S)-(+)-rolipram             | Phase 1          | phosphodiesterase inhibitor     | PDE4B|PDE4D                                                                                  | nan                  | nan                 |
# |  4 | [sar9,met(o2)11]-substance-p | Preclinical      | tachykinin antagonist           | TACR1                                                                                        | nan                  | nan                 |
# +----+------------------------------+------------------+---------------------------------+----------------------------------------------------------------------------------------------+----------------------+---------------------+
#
#  repurposing_drugs_20200324.txt  Dataframe (After processing):
#
# +----+------------------------------+------------------+---------------------------------+----------------------------------------------------------------------------------------------+----------------------+---------------------+
# |    | pert_iname                   | clinical_phase   | moa                             | target                                                                                       | disease_area         | indication          |
# |----+------------------------------+------------------+---------------------------------+----------------------------------------------------------------------------------------------+----------------------+---------------------|
# |  0 | (R)-(-)-apomorphine          | Launched         | dopamine receptor agonist       | ADRA2A|ADRA2B|ADRA2C|CALY|DRD1|DRD2|DRD3|DRD4|DRD5|HTR1A|HTR1B|HTR1D|HTR2A|HTR2B|HTR2C|HTR5A | neurology/psychiatry | Parkinson's Disease |
# |  1 | (R)-(-)-rolipram             | Phase 1          | phosphodiesterase inhibitor     | PDE4A|PDE4B|PDE4C|PDE4D|PDE5A                                                                | nan                  | nan                 |
# |  2 | (R)-baclofen                 | Phase 3          | benzodiazepine receptor agonist | GABBR1|GABBR2                                                                                | nan                  | nan                 |
# |  3 | (S)-(+)-rolipram             | Phase 1          | phosphodiesterase inhibitor     | PDE4B|PDE4D                                                                                  | nan                  | nan                 |
# |  4 | [sar9,met(o2)11]-substance-p | Preclinical      | tachykinin antagonist           | TACR1                                                                                        | nan                  | nan                 |
# +----+------------------------------+------------------+---------------------------------+----------------------------------------------------------------------------------------------+----------------------+---------------------+
#                         pert_iname clinical_phase
# 0              (R)-(-)-apomorphine       Launched  \
# 1                 (R)-(-)-rolipram        Phase 1
# 2                     (R)-baclofen        Phase 3
# 3                 (S)-(+)-rolipram        Phase 1
# 4     [sar9,met(o2)11]-substance-p    Preclinical
# ...                            ...            ...
# 6793                      8-M-PDOT    Preclinical
# 6794                    80841-78-7    Preclinical
# 6795               9-aminoacridine    Preclinical
# 6796           9-aminocamptothecin        Phase 2
# 6797   9-anthracenecarboxylic-acid    Preclinical
#
#                                   moa
# 0           dopamine receptor agonist  \
# 1         phosphodiesterase inhibitor
# 2     benzodiazepine receptor agonist
# 3         phosphodiesterase inhibitor
# 4               tachykinin antagonist
# ...                               ...
# 6793       melatonin receptor agonist
# 6794                              NaN
# 6795                              NaN
# 6796          topoisomerase inhibitor
# 6797                              NaN
#
#                                                  target          disease_area
# 0     ADRA2A|ADRA2B|ADRA2C|CALY|DRD1|DRD2|DRD3|DRD4|...  neurology/psychiatry  \
# 1                         PDE4A|PDE4B|PDE4C|PDE4D|PDE5A                   NaN
# 2                                         GABBR1|GABBR2                   NaN
# 3                                           PDE4B|PDE4D                   NaN
# 4                                                 TACR1                   NaN
# ...                                                 ...                   ...
# 6793                                      MTNR1A|MTNR1B                   NaN
# 6794                                                NaN                   NaN
# 6795                                                NaN                   NaN
# 6796                                               TOP1                   NaN
# 6797                                         ANO1|CLCN1                   NaN
#
#                indication
# 0     Parkinson's Disease
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# ...                   ...
# 6793                  NaN
# 6794                  NaN
# 6795                  NaN
# 6796                  NaN
# 6797                  NaN
#
# [6798 rows x 6 columns]
